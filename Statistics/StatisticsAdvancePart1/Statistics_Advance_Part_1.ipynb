# %% [markdown]
# #Statistics Advance Part 1

# %% [markdown]
# ##Theoritical Questions

# %% [markdown]
# ###1. What is a random variable in probability theory?
#
# Random variable is a variable that takes different random values, each associated with a probability.
# It is a function that assigns numerical values of a random phenomenon. Random variable helps to quantify outcomes that are not deterministic.
#
# ###2. What are the types of random variables?
#
# Discrete random variable - The outcomes are countable number of values. example - rolling of a dice
#
# Continuous random variable - The outcome can have any numerical values within a range.
# example - weight of students in a class.
#
# ###3.  What is the difference between discrete and continuous distributions?
#
# Discrete distribution
# Type of outcome are discrete. summation of all outcome probability is 1. Represented by Probability Mass Functions(PMF). Probability of each outcome is greater than or equal to 0. Example - Outcome from rolling of a dice.
#
# Continuous distribution
# Type of outcomes are continuous.Represented by probability density function(PDF).Area under the PDF is 1.
# Example - Temparature reading throughout the day.
#
#
# ###4. What are probability distribution functions (PDF)?
#
# PDF is a mathematical function that provides likelihood of the outcomes of a random variable.There are 2 types of PDF
# Probability Mass Function
# Probability Density function
#
# The key characteristics of PDF - Mean, Variance, Skewness
#
# ###5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# PDF is a mathematical function that provides likelihood of the outcomes of a random variable.It shows probability distribution across possible values.
#
# CDF is step by step accumulation of the probabilites.
# CDF ranges from 0 to 1
#
# PDF shows density of probabilites at specific points.CDF is used to show the probability of being below a specific value.
#
# ###6.  What is a discrete uniform distribution?
#
# Uniform distribution is a probability distribution.
# - Outcomes are finite
# - Outcomes are equally likely
# - If there are n possible outcomes, then probability of each one is 1/n
# ```
#  P(X=xi) = 1/n
#  ```
#
# ###7.  What are the key properties of a Bernoulli distribution?
#
# - Binary Outcomes
# - Only single trial
# - Probability of success = p, probability of failure is (1-p)
# - Expected value E(X) = p
# - variance is p(1-p)
# - PMF
# ```
# P(X=x) = p if x=1
# P(X=x) =(1-p)if x=0
# ```
#
# Example - probability of Head in a coin toss
#
# ###8. What is the binomial distribution, and how is it used in probability?
#
# Number of successes in a fixed number of independent Bernoulli trials.
#
# - Number of trials is fixed n
# - probability of success = p
#
# ```
# PMF = nck p**k (1-p)**(n-k)
# ```
# - Expected value E(X) = np
# - Variance  np(1-p)
#
# Example - Probability of getting 5 heads in an event of flipping 10 coins . n=10 k=5 p=0.5
#
# Usage - Identification of defective elements, Medical trials, Survey sampling.
#
#
# ###9. What is the Poisson distribution and where is it applied?
#
# Probaility of a given number of events, in a fixed time interval
#
# ```
# P(k,lambda) = e**-lambda * lambda **k/k!
#
# k is actual number of events
# lambda is the average number of eveents in the interval
# ```
# Example - Number of customers visitng a website in agiven interval of time. Number of calls at a call center.
#
#
# ###10.  What is a continuous uniform distribution?
#
# Continuous distribution where probability of each value within a given range is equally likely to occur
#
# ```
# f(x) = 1/(b-a) for a<=x<=b
# f(x) = 0 else
# ```
# - Expected value E(X) = (a+b)/2
# - variance (b-a)**2/12
#
# ###11.  What are the characteristics of a normal distribution?
#
# - Perfectly symettric around its mean
# - PDF takes bell shape
# - Mean = median = Mode
# - Follows empirical rule
#
# ###12. What is the standard normal distribution, and why is it important?
#
# Specific type of normal distribution where mean =0 standard deviation = 1
#
# It simplifies calculation the data for ML models & statistics
# Helps in calculating Z score
#
#
# ###13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# CLT states, if the sample is sufficintly large,the sample distribution of the sample mean of the population will follow normal distribution. Regardless of the original population distribution.
#
# It simplifies calculation & helps in hypothesis testing
#
#
# ###14. How does the Central Limit Theorem relate to the normal distribution?
#
# CLT states that for a suffficiently large sample, the sample mean will follow normal distribution. As the sample size increases the sample mean approaches normal distribution.
#
# ###15.  What is the application of Z statistics in hypothesis testing?
#
# In Hypothesis testing, z statistics provides a way to measure the difference between a sample mean & population mean, in terms of standard deviation.
#
#
# ###16. How do you calculate a Z-score, and what does it represent?
#
# -Find the mean μ
# -Find the standard deviation σ
# -Find the data point X
# -Calculate Z score (X-μ)/σ
#
# Z score represents how many standard deviation away a point is from the mean.
#
#
# ###17.  What are point estimates and interval estimates in statistics?
#
# Point estimate - Single value calculated from the sample to estimate the population, like mean, variance.
#
# Interval estimate - A range of value, between which the population parameter is expected to lie. Example - Confidence Interval.
#
#
# ###18. What is the significance of confidence intervals in statistical analysis?
#
# CI presents a range of value where the population parameter is expected to fall.Helps to take informed decision considering margin of error & compare different group of conditions.Also used in Hypothesis testing.
#
# ###19. What is the relationship between a Z-score and a confidence interval?
#
# Z scores are used to calculate the margin of error in a confidence interval. Z score is read from the z table. Margin of error is calculated from Z*(σ / √n).
# Confidence interval is sample mean + margin of error
#
#
# ###20. How are Z-scores used to compare different distributions?
# Z score converts the data into a standard scale, where mean = 0 & standard deviation =1. Wqith this data for different distribution, the data can be compared as those are now at same scale.
# Z score states how many standard deviation away, a data point is from mean. this a standard scale for any distribution to comapre.
#
# Example Scores of different exams of different students.
#
#
# ###21.  What are the assumptions for applying the Central Limit Theorem?
#
# -The data points should be independent
# -Sampling is random
# -Sample is size is large (n>30)
# -Samples should be identically distributed
#
# ###22. What is the concept of expected value in a probability distribution?
#
# It represents the mean of the random variable of a large number of trials.It's a long term average
#
# ```
# For discrete random variable
# 𝐸(𝑋)=𝑖=1𝑛∑[𝑥𝑖⋅𝑃(𝑥𝑖)]
#
# For continuous random variable
# 𝐸(𝑋)=−∞ ∞∫𝑥⋅𝑓(𝑥) 𝑑𝑥
#
# xi is the possible values of the random variable
# P(xi) is the probability of xi
# f(x) is the probability density function of the random variable
# ```
#
# ###23. How does a probability distribution relate to the expected outcome of a random variable??
#
# For discrete random variable
# Expected outcome is the summation of all the possible value * corresponding probability
#
#
# For continuous random variable
# Expected outcome is the integration of all possible values * the probability density

# %% [markdown]
# ## Practical Questions

# %%
###1.  Write a Python program to generate a random variable and display its value

import numpy as np

#continuous
random = np.random.random()
print(random)

#discrete
random = np.random.randint(1,10)
print(random)
# Out:
# 0.9064239147785513
# 6

# %%
###2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

import numpy as np
import matplotlib.pyplot as plt

#100 uniform random numbers from 1 to 100
random = np.random.randint(1,101,100)

values,counts = np.unique(random, return_counts=True)

pmf = counts/100

plt.stem(values,pmf)
plt.xlabel("Values")
plt.ylabel("Probabiltiy")
plt.title("PMF for Uniform discrete distribution")
plt.grid(True)
plt.show()

# %%
###3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

import numpy as np
import matplotlib.pyplot as plt

def calculate_bernoulli_pdf(p,x):
  if x not in [0,1]:
    raise ValueError("Only binary outcome allowed")
  elif not 0<=p<=1:
    raise ValueError("Probability shuld be between 0 & 1")
  return p if x==1 else 1-p

print(calculate_bernoulli_pdf(0.3,0))
print(calculate_bernoulli_pdf(0.3,1))
# Out:
# 0.7
# 0.3

# %%
###4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5

binomial = np.random.binomial(n,p,1000)
bins=np.arange(1, n+1, 1)

plt.hist(binomial,bins=bins,density=True)
plt.xlabel("Number of success")
plt.ylabel("Probability")
plt.xticks(bins)
plt.show()

# %%
###5. Create a Poisson distribution and visualize it using Python

import numpy as np
import matplotlib.pyplot as plt

lam = 10 #average event per interval

poisson = np.random.poisson(lam,1000)
bins = np.arange(0,10,1)
plt.hist(poisson,bins=bins, edgecolor='k')
plt.xlabel("Number of events")
plt.ylabel("Frequency")
plt.title(f"Poisson distribution with lambda ={lam}")
plt.xticks(bins)
plt.show()

# %%
###6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
##uniform distribution

import numpy as np
import matplotlib.pyplot as plt
from  scipy.stats import randint


x = np.arange(1,10,1)
cdf = randint.cdf(x,1,11)

plt.step(x,cdf,where='post', label='CDF')
plt.xlabel("Data")
plt.ylabel("Cummulative probability")
plt.title("CDF of Discrete Uniform Distribution")
plt.legend()
plt.grid()
plt.show()

# %%
###7. Generate a continuous uniform distribution using NumPy and visualize it

import numpy as np
import matplotlib.pyplot as plt

cont_uni_dist=np.random.uniform(1,10,size=10000)

plt.hist(cont_uni_dist,bins=40,edgecolor='k')
plt.xlabel("values")
plt.ylabel("frequency")
plt.title("Continuous uniform distribution")
plt.show()

# %%
###8. Simulate data from a normal distribution and plot its histogram

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

normal = np.random.normal(100,10,10000)
sns.histplot(normal,bins=10,kde=True)
plt.title("Normal distribution")
plt.xlabel("value")
plt.ylabel("Density")
plt.show()

# %%
###9.  Write a Python function to calculate Z-scores from a dataset and plot them

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_z_score(data):
  mean = np.mean(data)
  std = np.std(data)

  z_score = [(x-mean)/std for x in data]
  return z_score

def plot_z_score(z_score):
  sns.histplot(z_score,bins=50,kde= True)
  plt.title("Z Score Histogram")
  plt.xlabel("Z Score")
  plt.ylabel("Density")
  plt.show()

normal = np.random.normal(100,10,10000)
plot_z_score(calculate_z_score(normal))

# %%
###10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the Poisson distribution
lambda_value = 5
num_samples = 1000
sample_sizes = [5, 10, 30, 50, 100]

# Generate data from a Poisson distribution
data = np.random.poisson(lam=lambda_value, size=num_samples)

# Plot histograms of sample means for different sample sizes
for i, sample_size in enumerate(sample_sizes, 1):
    # Draw random samples and calculate their means
    sample_means = [np.mean(np.random.choice(data, sample_size)) for _ in range(num_samples)]

    # Plot histogram of sample means
    plt.subplot(2, 3, i)
    plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='g', label='Sample Means')

    # Fit a normal distribution to the sample means
    mu, std = norm.fit(sample_means)

    # Plot the fitted normal distribution
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)

    plt.plot(x, p, 'k', linewidth=2)
    plt.title(f'Sample Size = {sample_size}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
###15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 50
std_dev = 10
num_samples = 1000
sample_sizes = [5, 10, 30, 50, 100]

# Generate data from a normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=num_samples)

# Plot histograms of sample mean
for i, sample_size in enumerate(sample_sizes, 1):
    # Draw random samples and calculate their means
    sample_means = [np.mean(np.random.choice(data, sample_size)) for _ in range(num_samples)]

    # Plot histogram of sample means
    plt.subplot(2, 3, i)
    plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='g', label='Sample Means')

    # Fit a normal distribution to the sample means
    mu, std = norm.fit(sample_means)

    # Plot the fitted normal distribution
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)

    plt.plot(x, p, 'k', linewidth=2)
    plt.title(f'Sample Size = {sample_size}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
###16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def std_normal_dist(x):
  y = (1 / (np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
  sns.lineplot(x=x,y=y)
  plt.title("Standard Normal distribution")
  plt.xlabel("value")
  plt.ylabel("Density")
  plt.show()

x = np.linspace(-5,5,10000)
std_normal_dist(x)

# %%
###17. Generate random variables and calculate their corresponding probabilities using the binomial distribution
import numpy as np
from scipy.stats import binom

n = 10 #number of trials
p =0.5 # probability of success

random_variables = np.arange(n+1)

probability =  binom.pmf(random_variables,n,p)

for k,p in zip(random_variables,probability):
  print(f"P(X={k}) - probability is {p:.4f}")
# Out:
# P(X=0) - probability is 0.0010
# P(X=1) - probability is 0.0098
# P(X=2) - probability is 0.0439
# P(X=3) - probability is 0.1172
# P(X=4) - probability is 0.2051
# P(X=5) - probability is 0.2461
# P(X=6) - probability is 0.2051
# P(X=7) - probability is 0.1172
# P(X=8) - probability is 0.0439
# P(X=9) - probability is 0.0098
# P(X=10) - probability is 0.0010

# %%
###18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution

import numpy as np
from scipy.stats import norm

def calculate_z_score(dataset,data_point):
  mean = np.mean(dataset)
  std = np.std(dataset)
  z_score = (data_point -mean)/std
  return z_score

def std_normal_dist(x):
  y = (1 / (np.sqrt(2 * np.pi))) * np.exp(-0.5 * x**2)
  return y

data = np.random.randint(low=0,high=100,size=10)
for data_point in data:
  z_score = calculate_z_score(data,data_point)
  #Compare to standard normal distribution
  p_value = norm.pdf(data_point)
  print(f"Z score for {data_point} is {z_score}, p value for std normal dist is {p_value}")
# Out:
# Z score for 51 is 0.06702909610721228, p value for std normal dist is 0.0
# Z score for 86 is 1.301775603345334, p value for std normal dist is 0.0
# Z score for 99 is 1.7603957346052077, p value for std normal dist is 0.0
# Z score for 31 is -0.6385403366002859, p value for std normal dist is 8.363951605856463e-210
# Z score for 1 is -1.6968944856615331, p value for std normal dist is 0.24197072451914337
# Z score for 53 is 0.13758603937796207, p value for std normal dist is 0.0
# Z score for 32 is -0.603261864964911, p value for std normal dist is 1.746366256758777e-223
# Z score for 71 is 0.7725985288147104, p value for std normal dist is 0.0
# Z score for 22 is -0.95604658131866, p value for std normal dist is 3.1742815528252627e-106
# Z score for 45 is -0.14464173370503716, p value for std normal dist is 0.0

# %%
###19. Implement hypothesis testing using Z-statistics for a sample dataset


import numpy as np
from scipy.stats import norm

#Sample data
sample_data = [12, 15, 14, 10, 13, 14, 16, 15, 13, 14]
population_mean = 13
population_std = 2
significance_level = 0.05

sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data)
sample_size = len(sample_data)

#Z Stats
z_statistic = (sample_mean - population_mean) / (population_std  / np.sqrt(sample_size))

critical_value = norm.ppf(1 - significance_level / 2)
print(f"Critical value for significance level {significance_level}: ±{critical_value:.2f}")

# Hypothesis testing decision
if abs(z_statistic) > critical_value:
    print("Reject the null hypothesis (H0)")
else:
    print("Fail to reject the null hypothesis (H0)")
# Out:
# Critical value for significance level 0.05: ±1.96
# Fail to reject the null hypothesis (H0)

# %%
###20. Create a confidence interval for a dataset using Python and interpret the result

import numpy as np
from scipy import stats

# Sample dataset
data = [12, 15, 14, 10, 13, 14, 16, 15, 13, 14]

confidence = 0.95

sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data)
sample_size = len(sample_data)
std_error = sample_std / np.sqrt(sample_size)

critical_value = stats.t.ppf((1 + confidence) / 2, df=len(data) - 1)
margin_of_error = critical_value * std_error

lower_bound = sample_mean-margin_of_error
upper_bound = sample_mean+margin_of_error

print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# 95% Confidence Interval: (12.44, 14.76)

# %%
###21 Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

import numpy as np
from scipy import stats

# Generate random data from a normal distribution
data = np.random.normal(loc=50, scale=10, size=1000)

def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    std_error = np.std(data, ddof=1) / np.sqrt(len(data))
    h = std_error * stats.t.ppf((1 + confidence) / 2., len(data) - 1)
    return mean, mean - h, mean + h

# Calculate the 95% confidence interval
mean, lower_bound, upper_bound = confidence_interval(data)

print(f"Generated Data Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Generated Data Mean: 49.69
# 95% Confidence Interval: (49.05, 50.33)

# %%
###22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate random data from a normal distribution
mean =50
std_dev =10
data = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
pdf = norm.pdf(data,mean,std_dev)
plt.plot(data,pdf)
plt.title("Probability Density Function of Normal Distribution")
plt.xlabel("X")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-39-8273b07113f5>:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
###23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_val = 5
k = 15
x = np.arange(0, k + 1)

# Calculate the CDF
cdf = poisson.cdf(x, lambda_val)

# Plot the CDF
plt.figure(figsize=(8, 6))
plt.step(x, cdf, where='mid', label=f"λ = {lambda_val}")
plt.title("Cumulative Distribution Function of Poisson Distribution")
plt.xlabel("k")
plt.ylabel("Cumulative Probability")
plt.legend()
plt.grid(True)
plt.show()

# %%
###24. Simulate a random variable using a continuous uniform distribution and calculate its expected value

import numpy as np
import scipy.integrate as integrate

a =10
b = 20

size = 1000  # number of samples

# Generate data from the uniform distribution
data = np.random.uniform(a, b, size)


# Define the PDF of the uniform distribution
def uniform_pdf(x, a, b):
    if a <= x <= b:
        return 1 / (b - a)
    else:
        return 0

# Integrate to calculate the expected value
expected_value, _ = integrate.quad(lambda x: x * uniform_pdf(x, a, b), a, b)

print(f"Expected Value calculated using the integral formula: {expected_value:.2f}")
print(f"Expected Value calculated using the mean: {np.mean(data):.2f}")
# Out:
# Expected Value calculated using the integral formula: 15.00
# Expected Value calculated using the mean: 15.05

# %%
###25. Write a Python program to compare the standard deviations of two datasets and visualize the difference

import numpy as np
import matplotlib.pyplot as plt

# Sample datasets
data1 = [10, 12, 23, 23, 16, 23, 21, 16, 12, 21]
data2 = [20, 25, 20, 21, 22, 24, 26, 27, 28, 23]

# Calculate standard deviations
std_dev1 = np.std(data1, ddof=1)
std_dev2 = np.std(data2, ddof=1)

# Create a bar chart
labels = ['Dataset 1', 'Dataset 2']
std_devs = [std_dev1, std_dev2]

plt.bar(labels, std_devs, color=['blue', 'orange'])
plt.title('Comparison of Standard Deviations')
plt.ylabel('Standard Deviation')
plt.show()

print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")
# Out:
# Standard Deviation of Dataset 1: 5.12
# Standard Deviation of Dataset 2: 2.88

# %%
###26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

import numpy as np

# Parameters for the normal distribution
mean = 50
std_dev = 10
size = 1000

# Generate data from the normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Calculate the range
data_range = np.ptp(data)

# Calculate the interquartile range (IQR)
q1, q3 = np.percentile(data, [25, 75])
iqr = q3 - q1

print(f"Range of the Dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the Dataset: {iqr:.2f}")
# Out:
# Range of the Dataset: 63.32
# Interquartile Range (IQR) of the Dataset: 13.53

# %%
###27. Implement Z-score normalization on a dataset and visualize its transformation

import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    normalized_data = (data - mean) / std_dev
    return normalized_data

# Generate data from a normal distribution
mean = 50
std_dev = 10
num_samples = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=num_samples)

# Perform Z-score normalization
normalized_data = z_score_normalization(data)

# Plot the original data and normalized data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='blue', alpha=0.7, label='Original Data')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='green', alpha=0.7, label='Normalized Data')
plt.title('Z-score Normalized Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
###28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

import numpy as np
from scipy.stats import skew, kurtosis

# Generate data from a normal distribution
mean = 50
std_dev = 10
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Calculate skewness and kurtosis
skewness = skew(data)
kurt = kurtosis(data)

print(f"Skewness of the Dataset: {skewness:.2f}")
print(f"Kurtosis of the Dataset: {kurt:.2f}")
# Out:
# Skewness of the Dataset: 0.05
# Kurtosis of the Dataset: 0.09
