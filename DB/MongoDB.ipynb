# %% [markdown]
# #Theoritical

# %% [markdown]
# ###1. What are the key differences between SQL and NoSQL databases
#
# - SQL databases
#   - stores relational data in tabular format
#   - Supports SQL languange
#   - ACID compliant
#   - Fixed schema
#
# - NoSQL databases
#   - Stores not relational data like key-value , graph etc
#   - Doesnot support SQL
#   - BASE compliant
#   - Not fixed schema
#
#
# ###2. What makes MongoDB a good choice for modern applications
#
#  - Document oriented
#  - Flexible schema
#  - High performance for read/write operations
#  - Cloud-native with MongoDB Atlas
#  - Rich query and aggregation capabilities
#
# ###3. Explain the concept of collections in MongoDB
# Collection is a group of related documents that are stored together
#
# ###4. How does MongoDB ensure high availability using replication
# MongoDB ensures high availability through replica sets, which maintain multiple synchronized copies of data in multiple servers
#
# ###5. What are the main benefits of MongoDB Atlas
# MongoDB Atlas offers a fully managed, scalable, and secure cloud database solution with automated backups, global distribution, and real-time performance monitoring
#
# ###6. What is the role of indexes in MongoDB, and how do they improve performance
# Indexes in MongoDB accelerate query performance by allowing efficient data retrieval without scanning the entire collection
#
# ###7. Describe the stages of the MongoDB aggregation pipeline
# The MongoDB aggregation pipeline processes documents through sequential stages like $match, $group, $project, $sort, and others to filter, transform, and analyze data
#
# ###8. What is sharding in MongoDB? How does it differ from replication
# Sharding in MongoDB splits data across multiple servers for scalability, while replication copies data across servers for high availability and fault tolerance.
#
# ###9. What is PyMongo, and why is it used
# PyMongo is the Python driver for MongoDB, used to interact with MongoDB databases using Python code
#
# ###10. What are the ACID properties in the context of MongoDB transactions
# ACID properties in MongoDB ensure that transactions are Atomic, maintain Consistency, operate in Isolation, and guarantee Durability, preserving data integrity even in complex operations.
#
# ###11. What is the purpose of MongoDB’s explain() function
# The explain() function in MongoDB reveals how a query or operation is executed, helps analyze performance and optimize indexes
#
# ###12. How does MongoDB handle schema validation
# MongoDB handles schema validation using the $jsonSchema operator, which allows you to define rules for document structure
#
# ###13. What is the difference between a primary and a secondary node in a replica set
# In a MongoDB replica set, the primary node handles all write operations, while secondary nodes replicate data from the primary and serve read operations as needed
#
# ###14. What security mechanisms does MongoDB provide for data protection
# MongoDB provides authentication, authorization, encryption (in transit and at rest), auditing, and network access controls to ensure comprehensive data protection
#
# ###15. Explain the concept of embedded documents and when they should be used
# In MongoDB, embedded documents are nested structures within a document, best used when related data is frequently accessed together and fits within the 16MB document size limit.
#
# ###16. What is the purpose of MongoDB’s $lookup stage in aggregation
# The $lookup stage in MongoDB performs a left outer join to combine documents from two collections based on a related field, enabling relational-style queries within a NoSQL database
#
# ###17. What are some common use cases for MongoDB
#
#   - Content management systems
#   - Real-time analytics
#   - Mobile and web applications
#   - Product catalogs and inventory management
#   - E-commerce platforms
#   - Log and event data storage
#   - AI and machine learning pipelines
#
# ###18. What are the advantages of using MongoDB for horizontal scaling
# MongoDB enables horizontal scaling through sharding, allowing seamless distribution of data across multiple servers to handle large-scale workloads with high availability and performance.
#
# ###19. How do MongoDB transactions differ from SQL transactions
# SQL databases are built around multi-statement ACID transactions
#
# MongoDB introduced multi-document ACID transactions later
#
# MongoDB encourages embedding related data to minimize the need for complex joins and transactions
# SQL relies heavily on normalized schemas and transactional integrity across multiple tables.
#
# ###20. What are the main differences between capped collections and regular collections
# Capped collections in MongoDB have a fixed size and overwrite old data in insertion order, while regular collections grow dynamically and retain all inserted documents
#
# ###21. What is the purpose of the $match stage in MongoDB’s aggregation pipeline
#
# The $match stage in MongoDB’s aggregation pipeline filters documents based on specified criteria
#
# ###22. How can you secure access to a MongoDB database
# Access can be secured by
#   - enabling authentication
#   - enforcing role-based access control
#   - encrypting data
#    - restricting network access through IP whitelisting.
#
# ###23. What is MongoDB’s WiredTiger storage engine, and why is it important?
# WiredTiger storage engine is the default engine that powers how data is stored and accessed
#
# designed for high performance, concurrency, and efficiency
#
# It supports document-level locking, which allows multiple write operations to occur simultaneously

# %% [markdown]
# # Practical

# %%
###1. Write a Python script to load the Superstore dataset from a CSV file into MongoDB

#!pip install "pymongo[srv]"==3.6 -qU
# #!pip install 'pymongo<4.9'
# !pip uninstall pymongo
# !pip uninstall motor  # or any related library
# !pip install 'pymongo<4.9'

uri = "mongodb+srv://debduttachatterjee09:<pwd>@cluster0.bhxnbpf.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
from pymongo import MongoClient

client = MongoClient(
    uri
)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/superstore.csv', encoding='latin1')
df.columns = df.columns.str.replace(' ', '_').str.replace(r'[^\w]', '', regex=True)
data = df.to_dict(orient='records')
client = MongoClient(
    uri
)

db = client['superstoreDB']
collections = db['orders']

if data:
  collections.insert_many(data)
  print(f'inserted {len(data)} records')
else:
  print('No data found')
# Out:
# inserted 9994 records

# %%
###2. Retrieve and print all documents from the Orders collection

documents = collections.find().limit(5)

for doc in documents:
  print(doc)
# Out:
# {'_id': ObjectId('685966dd8718115e852b3293'), 'Row_ID': 1, 'Order_ID': 'CA-2016-152156', 'Order_Date': '11/8/2016', 'Ship_Date': '11/11/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'CG-12520', 'Customer_Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal_Code': 42420, 'Region': 'South', 'Product_ID': 'FUR-BO-10001798', 'Category': 'Furniture', 'SubCategory': 'Bookcases', 'Product_Name': 'Bush Somerset Collection Bookcase', 'Sales': 261.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 41.9136}
# {'_id': ObjectId('685966dd8718115e852b3294'), 'Row_ID': 2, 'Order_ID': 'CA-2016-152156', 'Order_Date': '11/8/2016', 'Ship_Date': '11/11/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'CG-12520', 'Customer_Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal_Code': 42420, 'Region': 'South', 'Product_ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'SubCategory': 'Chairs', 'Product_Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 731.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 219.582}
# {'_id': ObjectId('685966dd8718115e852b3295'), 'Row_ID': 3, 'Order_ID': 'CA-2016-138688', 'Order_Date': '6/12/2016', 'Ship_Date': '6/16/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DV-13045', 'Customer_Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90036, 'Region': 'West', 'Product_ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'SubCategory': 'Labels', 'Product_Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}
# {'_id': ObjectId('685966dd8718115e852b3296'), 'Row_ID': 4, 'Order_ID': 'US-2015-108966', 'Order_Date': '10/11/2015', 'Ship_Date': '10/18/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'SO-20335', 'Customer_Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal_Code': 33311, 'Region': 'South', 'Product_ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 957.5775, 'Quantity': 5, 'Discount': 0.45, 'Profit': -383.031}
# {'_id': ObjectId('685966dd8718115e852b3297'), 'Row_ID': 5, 'Order_ID': 'US-2015-108966', 'Order_Date': '10/11/2015', 'Ship_Date': '10/18/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'SO-20335', 'Customer_Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal_Code': 33311, 'Region': 'South', 'Product_ID': 'OFF-ST-10000760', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': "Eldon Fold 'N Roll Cart System", 'Sales': 22.368, 'Quantity': 2, 'Discount': 0.2, 'Profit': 2.5164}

# %%
###3. Count and display the total number of documents in the Orders collection

print(f"Total records in collection {collections.count_documents({})}")
# Out:
# Total records in collection 9994

# %%
###4. Write a query to fetch all orders from the "West" region

west_region_orders = collections.find({'Region':'West'},{})
for doc in west_region_orders:
  print(doc)
# Out:
# {'_id': ObjectId('685966dd8718115e852b3295'), 'Row_ID': 3, 'Order_ID': 'CA-2016-138688', 'Order_Date': '6/12/2016', 'Ship_Date': '6/16/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DV-13045', 'Customer_Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90036, 'Region': 'West', 'Product_ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'SubCategory': 'Labels', 'Product_Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}
# {'_id': ObjectId('685966dd8718115e852b3298'), 'Row_ID': 6, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'FUR-FU-10001487', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood', 'Sales': 48.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 14.1694}
# {'_id': ObjectId('685966dd8718115e852b3299'), 'Row_ID': 7, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-AR-10002833', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Newell 322', 'Sales': 7.28, 'Quantity': 4, 'Discount': 0.0, 'Profit': 1.9656}
# {'_id': ObjectId('685966dd8718115e852b329a'), 'Row_ID': 8, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'TEC-PH-10002275', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('685966dd8718115e852b329b'), 'Row_ID': 9, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-BI-10003910', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'DXL Angle-View Binders with Locking Rings by Samsill', 'Sales': 18.504, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.7825}
# {'_id': ObjectId('685966dd8718115e852b329c'), 'Row_ID': 10, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-AP-10002892', 'Category': 'Office Supplies', 'SubCategory': 'Appliances', 'Product_Name': 'Belkin F5C206VTEL 6 Outlet Surge', 'Sales': 114.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 34.47}
# {'_id': ObjectId('685966dd8718115e852b329d'), 'Row_ID': 11, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('685966dd8718115e852b329e'), 'Row_ID': 12, 'Order_ID': 'CA-2014-115812', 'Order_Date': '6/9/2014', 'Ship_Date': '6/14/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BH-11710', 'Customer_Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'TEC-PH-10002033', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('685966dd8718115e852b32a0'), 'Row_ID': 14, 'Order_ID': 'CA-2016-161389', 'Order_Date': '12/5/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'IM-15070', 'Customer_Name': 'Irene Maddox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal_Code': 98103, 'Region': 'West', 'Product_ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 407.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 132.5922}
# {'_id': ObjectId('685966dd8718115e852b32a4'), 'Row_ID': 18, 'Order_ID': 'CA-2014-167164', 'Order_Date': '5/13/2014', 'Ship_Date': '5/15/2014', 'Ship_Mode': 'Second Class', 'Customer_ID': 'AG-10270', 'Customer_Name': 'Alejandro Grove', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'West Jordan', 'State': 'Utah', 'Postal_Code': 84084, 'Region': 'West', 'Product_ID': 'OFF-ST-10000107', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Fellowes Super Stor/Drawer', 'Sales': 55.5, 'Quantity': 2, 'Discount': 0.0, 'Profit': 9.99}
# {'_id': ObjectId('685966dd8718115e852b32a5'), 'Row_ID': 19, 'Order_ID': 'CA-2014-143336', 'Order_Date': '8/27/2014', 'Ship_Date': '9/1/2014', 'Ship_Mode': 'Second Class', 'Customer_ID': 'ZD-21925', 'Customer_Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'OFF-AR-10003056', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Newell 341', 'Sales': 8.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.4824}
# {'_id': ObjectId('685966dd8718115e852b32a6'), 'Row_ID': 20, 'Order_ID': 'CA-2014-143336', 'Order_Date': '8/27/2014', 'Ship_Date': '9/1/2014', 'Ship_Mode': 'Second Class', 'Customer_ID': 'ZD-21925', 'Customer_Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'TEC-PH-10001949', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Cisco SPA 501G IP Phone', 'Sales': 213.48, 'Quantity': 3, 'Discount': 0.2, 'Profit': 16.011}
# {'_id': ObjectId('685966dd8718115e852b32a7'), 'Row_ID': 21, 'Order_ID': 'CA-2014-143336', 'Order_Date': '8/27/2014', 'Ship_Date': '9/1/2014', 'Ship_Mode': 'Second Class', 'Customer_ID': 'ZD-21925', 'Customer_Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'OFF-BI-10002215', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Wilson Jones Hanging View Binder, White, 1"', 'Sales': 22.72, 'Quantity': 4, 'Discount': 0.2, 'Profit': 7.384}
# {'_id': ObjectId('685966dd8718115e852b32ab'), 'Row_ID': 25, 'Order_ID': 'CA-2015-106320', 'Order_Date': '9/25/2015', 'Ship_Date': '9/30/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'EB-13870', 'Customer_Name': 'Emily Burns', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Orem', 'State': 'Utah', 'Postal_Code': 84057, 'Region': 'West', 'Product_ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 1044.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 240.2649}
# {'_id': ObjectId('685966dd8718115e852b32ac'), 'Row_ID': 26, 'Order_ID': 'CA-2016-121755', 'Order_Date': '1/16/2016', 'Ship_Date': '1/20/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'EH-13945', 'Customer_Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90049, 'Region': 'West', 'Product_ID': 'OFF-BI-10001634', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Wilson Jones Active Use Binders', 'Sales': 11.648, 'Quantity': 2, 'Discount': 0.2, 'Profit': 4.2224}
# {'_id': ObjectId('685966dd8718115e852b32ad'), 'Row_ID': 27, 'Order_ID': 'CA-2016-121755', 'Order_Date': '1/16/2016', 'Ship_Date': '1/20/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'EH-13945', 'Customer_Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90049, 'Region': 'West', 'Product_ID': 'TEC-AC-10003027', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Imation\xa08GB Mini TravelDrive USB 2.0\xa0Flash Drive', 'Sales': 90.57, 'Quantity': 3, 'Discount': 0.0, 'Profit': 11.7741}
# {'_id': ObjectId('685966dd8718115e852b32bd'), 'Row_ID': 43, 'Order_ID': 'CA-2016-101343', 'Order_Date': '7/17/2016', 'Ship_Date': '7/22/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'RA-19885', 'Customer_Name': 'Ruben Ausman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90049, 'Region': 'West', 'Product_ID': 'OFF-ST-10003479', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Eldon Base for stackable storage shelf, platinum', 'Sales': 77.88, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.894}
# {'_id': ObjectId('685966dd8718115e852b32d1'), 'Row_ID': 63, 'Order_ID': 'CA-2015-135545', 'Order_Date': '11/24/2015', 'Ship_Date': '11/30/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KM-16720', 'Customer_Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'TEC-AC-10004633', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack', 'Sales': 13.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.1512}
# {'_id': ObjectId('685966dd8718115e852b32d2'), 'Row_ID': 64, 'Order_ID': 'CA-2015-135545', 'Order_Date': '11/24/2015', 'Ship_Date': '11/30/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KM-16720', 'Customer_Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'OFF-BI-10001078', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"', 'Sales': 25.824, 'Quantity': 6, 'Discount': 0.2, 'Profit': 9.3612}
# {'_id': ObjectId('685966dd8718115e852b32d3'), 'Row_ID': 65, 'Order_ID': 'CA-2015-135545', 'Order_Date': '11/24/2015', 'Ship_Date': '11/30/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KM-16720', 'Customer_Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'OFF-PA-10003892', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1943', 'Sales': 146.73, 'Quantity': 3, 'Discount': 0.0, 'Profit': 68.9631}
# {'_id': ObjectId('685966dd8718115e852b32d4'), 'Row_ID': 66, 'Order_ID': 'CA-2015-135545', 'Order_Date': '11/24/2015', 'Ship_Date': '11/30/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KM-16720', 'Customer_Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'FUR-FU-10000397', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Luxo Economy Swing Arm Lamp', 'Sales': 79.76, 'Quantity': 4, 'Discount': 0.0, 'Profit': 22.3328}
# {'_id': ObjectId('685966dd8718115e852b32d6'), 'Row_ID': 68, 'Order_ID': 'CA-2014-106376', 'Order_Date': '12/5/2014', 'Ship_Date': '12/10/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BS-11590', 'Customer_Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal_Code': 85234, 'Region': 'West', 'Product_ID': 'OFF-AR-10002671', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige', 'Sales': 1113.024, 'Quantity': 8, 'Discount': 0.2, 'Profit': 111.3024}
# {'_id': ObjectId('685966dd8718115e852b32d7'), 'Row_ID': 69, 'Order_ID': 'CA-2014-106376', 'Order_Date': '12/5/2014', 'Ship_Date': '12/10/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'BS-11590', 'Customer_Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal_Code': 85234, 'Region': 'West', 'Product_ID': 'TEC-PH-10002726', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'netTALK DUO VoIP Telephone Service', 'Sales': 167.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 62.988}
# {'_id': ObjectId('685966dd8718115e852b32e4'), 'Row_ID': 82, 'Order_ID': 'CA-2014-139451', 'Order_Date': '10/12/2014', 'Ship_Date': '10/16/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DN-13690', 'Customer_Name': 'Duane Noonan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'OFF-AR-10002053', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Premium Writing Pencils, Soft, #2 by Central Association for the Blind', 'Sales': 14.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 4.172}
# {'_id': ObjectId('685966dd8718115e852b32e5'), 'Row_ID': 83, 'Order_ID': 'CA-2014-139451', 'Order_Date': '10/12/2014', 'Ship_Date': '10/16/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DN-13690', 'Customer_Name': 'Duane Noonan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'OFF-ST-10002370', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Sortfiler Multipurpose Personal File Organizer, Black', 'Sales': 21.39, 'Quantity': 1, 'Discount': 0.0, 'Profit': 6.2031}
# {'_id': ObjectId('685966dd8718115e852b32ec'), 'Row_ID': 90, 'Order_ID': 'CA-2016-109806', 'Order_Date': '9/17/2016', 'Ship_Date': '9/22/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JS-15685', 'Customer_Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90036, 'Region': 'West', 'Product_ID': 'OFF-AR-10004930', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Turquoise Lead Holder with Pocket Clip', 'Sales': 20.1, 'Quantity': 3, 'Discount': 0.0, 'Profit': 6.633}
# {'_id': ObjectId('685966dd8718115e852b32ed'), 'Row_ID': 91, 'Order_ID': 'CA-2016-109806', 'Order_Date': '9/17/2016', 'Ship_Date': '9/22/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JS-15685', 'Customer_Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90036, 'Region': 'West', 'Product_ID': 'TEC-PH-10004093', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Panasonic Kx-TS550', 'Sales': 73.584, 'Quantity': 2, 'Discount': 0.2, 'Profit': 8.2782}
# {'_id': ObjectId('685966dd8718115e852b32ee'), 'Row_ID': 92, 'Order_ID': 'CA-2016-109806', 'Order_Date': '9/17/2016', 'Ship_Date': '9/22/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JS-15685', 'Customer_Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90036, 'Region': 'West', 'Product_ID': 'OFF-PA-10000304', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1995', 'Sales': 6.48, 'Quantity': 1, 'Discount': 0.0, 'Profit': 3.1104}
# {'_id': ObjectId('685966dd8718115e852b32f2'), 'Row_ID': 96, 'Order_ID': 'US-2017-109484', 'Order_Date': '11/6/2017', 'Ship_Date': '11/12/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'RB-19705', 'Customer_Name': 'Roger Barcio', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal_Code': 97206, 'Region': 'West', 'Product_ID': 'OFF-BI-10004738', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Flexible Leather- Look Classic Collection Ring Binder', 'Sales': 5.682, 'Quantity': 1, 'Discount': 0.7, 'Profit': -3.788}
# {'_id': ObjectId('685966dd8718115e852b32f4'), 'Row_ID': 98, 'Order_ID': 'CA-2017-157833', 'Order_Date': '6/17/2017', 'Ship_Date': '6/20/2017', 'Ship_Mode': 'First Class', 'Customer_ID': 'KD-16345', 'Customer_Name': 'Katherine Ducich', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'OFF-BI-10001721', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Trimflex Flexible Post Binders', 'Sales': 51.312, 'Quantity': 3, 'Discount': 0.2, 'Profit': 17.9592}
# {'_id': ObjectId('685966dd8718115e852b32fa'), 'Row_ID': 104, 'Order_ID': 'US-2015-156867', 'Order_Date': '11/13/2015', 'Ship_Date': '11/17/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16870', 'Customer_Name': 'Lena Cacioppo', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Aurora', 'State': 'Colorado', 'Postal_Code': 80013, 'Region': 'West', 'Product_ID': 'TEC-AC-10001552', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Logitech K350 2.4Ghz Wireless Keyboard', 'Sales': 238.896, 'Quantity': 6, 'Discount': 0.2, 'Profit': -26.8758}
# {'_id': ObjectId('685966dd8718115e852b32fb'), 'Row_ID': 105, 'Order_ID': 'US-2015-156867', 'Order_Date': '11/13/2015', 'Ship_Date': '11/17/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16870', 'Customer_Name': 'Lena Cacioppo', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Aurora', 'State': 'Colorado', 'Postal_Code': 80013, 'Region': 'West', 'Product_ID': 'FUR-FU-10004006', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Deflect-o DuraMat Lighweight, Studded, Beveled Mat for Low Pile Carpeting', 'Sales': 102.36, 'Quantity': 3, 'Discount': 0.2, 'Profit': -3.8385}
# {'_id': ObjectId('685966dd8718115e852b32fc'), 'Row_ID': 106, 'Order_ID': 'US-2015-156867', 'Order_Date': '11/13/2015', 'Ship_Date': '11/17/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16870', 'Customer_Name': 'Lena Cacioppo', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Aurora', 'State': 'Colorado', 'Postal_Code': 80013, 'Region': 'West', 'Product_ID': 'OFF-BI-10002794', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets', 'Sales': 36.882, 'Quantity': 3, 'Discount': 0.7, 'Profit': -25.8174}
# {'_id': ObjectId('685966dd8718115e852b3308'), 'Row_ID': 118, 'Order_ID': 'CA-2015-110457', 'Order_Date': '3/2/2015', 'Ship_Date': '3/6/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DK-13090', 'Customer_Name': 'Dave Kipp', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal_Code': 98103, 'Region': 'West', 'Product_ID': 'FUR-TA-10001768', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Hon Racetrack Conference Tables', 'Sales': 787.53, 'Quantity': 3, 'Discount': 0.0, 'Profit': 165.3813}
# {'_id': ObjectId('685966dd8718115e852b3311'), 'Row_ID': 127, 'Order_ID': 'US-2017-107272', 'Order_Date': '11/5/2017', 'Ship_Date': '11/12/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'TS-21610', 'Customer_Name': 'Troy Staebel', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal_Code': 85023, 'Region': 'West', 'Product_ID': 'OFF-BI-10003274', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Avery Durable Slant Ring Binders, No Labels', 'Sales': 2.388, 'Quantity': 2, 'Discount': 0.7, 'Profit': -1.8308}
# {'_id': ObjectId('685966dd8718115e852b3312'), 'Row_ID': 128, 'Order_ID': 'US-2017-107272', 'Order_Date': '11/5/2017', 'Ship_Date': '11/12/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'TS-21610', 'Customer_Name': 'Troy Staebel', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal_Code': 85023, 'Region': 'West', 'Product_ID': 'OFF-ST-10002974', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Trav-L-File Heavy-Duty Shuttle II, Black', 'Sales': 243.992, 'Quantity': 7, 'Discount': 0.2, 'Profit': 30.499}
# {'_id': ObjectId('685966dd8718115e852b3313'), 'Row_ID': 129, 'Order_ID': 'US-2016-125969', 'Order_Date': '11/6/2016', 'Ship_Date': '11/10/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'LS-16975', 'Customer_Name': 'Lindsay Shagiari', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'FUR-CH-10001146', 'Category': 'Furniture', 'SubCategory': 'Chairs', 'Product_Name': 'Global Task Chair, Black', 'Sales': 81.424, 'Quantity': 2, 'Discount': 0.2, 'Profit': -9.1602}
# {'_id': ObjectId('685966dd8718115e852b3314'), 'Row_ID': 130, 'Order_ID': 'US-2016-125969', 'Order_Date': '11/6/2016', 'Ship_Date': '11/10/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'LS-16975', 'Customer_Name': 'Lindsay Shagiari', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'FUR-FU-10003773', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Eldon Cleatmat Plus Chair Mats for High Pile Carpets', 'Sales': 238.56, 'Quantity': 3, 'Discount': 0.0, 'Profit': 26.2416}
# {'_id': ObjectId('685966dd8718115e852b3318'), 'Row_ID': 134, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'OFF-PA-10001804', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 195', 'Sales': 20.04, 'Quantity': 3, 'Discount': 0.0, 'Profit': 9.6192}
# {'_id': ObjectId('685966dd8718115e852b3319'), 'Row_ID': 135, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'OFF-PA-10001736', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1880', 'Sales': 35.44, 'Quantity': 1, 'Discount': 0.0, 'Profit': 16.6568}
# {'_id': ObjectId('685966dd8718115e852b331a'), 'Row_ID': 136, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'OFF-AR-10001149', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Sanford Colorific Colored Pencils, 12/Box', 'Sales': 11.52, 'Quantity': 4, 'Discount': 0.0, 'Profit': 3.456}
# {'_id': ObjectId('685966dd8718115e852b331b'), 'Row_ID': 137, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'OFF-FA-10002988', 'Category': 'Office Supplies', 'SubCategory': 'Fasteners', 'Product_Name': 'Ideal Clamps', 'Sales': 4.02, 'Quantity': 2, 'Discount': 0.0, 'Profit': 1.9698}
# {'_id': ObjectId('685966dd8718115e852b331c'), 'Row_ID': 138, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'OFF-BI-10004781', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'GBC Wire Binding Strips', 'Sales': 76.176, 'Quantity': 3, 'Discount': 0.2, 'Profit': 26.6616}
# {'_id': ObjectId('685966dd8718115e852b331d'), 'Row_ID': 139, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'OFF-SU-10001218', 'Category': 'Office Supplies', 'SubCategory': 'Supplies', 'Product_Name': 'Fiskars Softgrip Scissors', 'Sales': 65.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 18.4464}
# {'_id': ObjectId('685966dd8718115e852b331e'), 'Row_ID': 140, 'Order_ID': 'CA-2016-145583', 'Order_Date': '10/13/2016', 'Ship_Date': '10/19/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LC-16885', 'Customer_Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal_Code': 95661, 'Region': 'West', 'Product_ID': 'FUR-FU-10001706', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Longer-Life Soft White Bulbs', 'Sales': 43.12, 'Quantity': 14, 'Discount': 0.0, 'Profit': 20.6976}
# {'_id': ObjectId('685966dd8718115e852b3320'), 'Row_ID': 142, 'Order_ID': 'CA-2017-106180', 'Order_Date': '9/18/2017', 'Ship_Date': '9/23/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'SH-19975', 'Customer_Name': 'Sally Hughsby', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'OFF-AR-10000940', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Newell 343', 'Sales': 8.82, 'Quantity': 3, 'Discount': 0.0, 'Profit': 2.3814}
# {'_id': ObjectId('685966dd8718115e852b3321'), 'Row_ID': 143, 'Order_ID': 'CA-2017-106180', 'Order_Date': '9/18/2017', 'Ship_Date': '9/23/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'SH-19975', 'Customer_Name': 'Sally Hughsby', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'OFF-EN-10004030', 'Category': 'Office Supplies', 'SubCategory': 'Envelopes', 'Product_Name': 'Convenience Packs of Business Envelopes', 'Sales': 10.86, 'Quantity': 3, 'Discount': 0.0, 'Profit': 5.1042}
# {'_id': ObjectId('685966dd8718115e852b3322'), 'Row_ID': 144, 'Order_ID': 'CA-2017-106180', 'Order_Date': '9/18/2017', 'Ship_Date': '9/23/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'SH-19975', 'Customer_Name': 'Sally Hughsby', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'OFF-PA-10004327', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1911', 'Sales': 143.7, 'Quantity': 3, 'Discount': 0.0, 'Profit': 68.976}
# {'_id': ObjectId('685966dd8718115e852b3324'), 'Row_ID': 146, 'Order_ID': 'CA-2015-110744', 'Order_Date': '9/7/2015', 'Ship_Date': '9/12/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'HA-14920', 'Customer_Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Pasadena', 'State': 'California', 'Postal_Code': 91104, 'Region': 'West', 'Product_ID': 'OFF-ST-10003656', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Safco Industrial Wire Shelving', 'Sales': 671.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 20.1579}
# {'_id': ObjectId('685966dd8718115e852b332a'), 'Row_ID': 152, 'Order_ID': 'CA-2016-158834', 'Order_Date': '3/13/2016', 'Ship_Date': '3/16/2016', 'Ship_Mode': 'First Class', 'Customer_ID': 'TW-21025', 'Customer_Name': 'Tamara Willingham', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Scottsdale', 'State': 'Arizona', 'Postal_Code': 85254, 'Region': 'West', 'Product_ID': 'OFF-AP-10000326', 'Category': 'Office Supplies', 'SubCategory': 'Appliances', 'Product_Name': 'Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection', 'Sales': 157.92, 'Quantity': 5, 'Discount': 0.2, 'Profit': 17.766}
# {'_id': ObjectId('685966dd8718115e852b332b'), 'Row_ID': 153, 'Order_ID': 'CA-2016-158834', 'Order_Date': '3/13/2016', 'Ship_Date': '3/16/2016', 'Ship_Mode': 'First Class', 'Customer_ID': 'TW-21025', 'Customer_Name': 'Tamara Willingham', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Scottsdale', 'State': 'Arizona', 'Postal_Code': 85254, 'Region': 'West', 'Product_ID': 'TEC-PH-10001254', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Jabra BIZ 2300 Duo QD Duo Corded\xa0Headset', 'Sales': 203.184, 'Quantity': 2, 'Discount': 0.2, 'Profit': 15.2388}
# {'_id': ObjectId('685966dd8718115e852b332c'), 'Row_ID': 154, 'Order_ID': 'CA-2015-124919', 'Order_Date': '5/31/2015', 'Ship_Date': '6/2/2015', 'Ship_Mode': 'First Class', 'Customer_ID': 'SP-20650', 'Customer_Name': 'Stephanie Phelps', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Jose', 'State': 'California', 'Postal_Code': 95123, 'Region': 'West', 'Product_ID': 'OFF-PA-10001950', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Southworth 25% Cotton Antique Laid Paper & Envelopes', 'Sales': 58.38, 'Quantity': 7, 'Discount': 0.0, 'Profit': 26.271}
# {'_id': ObjectId('685966dd8718115e852b332d'), 'Row_ID': 155, 'Order_ID': 'CA-2015-124919', 'Order_Date': '5/31/2015', 'Ship_Date': '6/2/2015', 'Ship_Mode': 'First Class', 'Customer_ID': 'SP-20650', 'Customer_Name': 'Stephanie Phelps', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Jose', 'State': 'California', 'Postal_Code': 95123, 'Region': 'West', 'Product_ID': 'OFF-PA-10002254', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1883', 'Sales': 105.52, 'Quantity': 4, 'Discount': 0.0, 'Profit': 48.5392}
# {'_id': ObjectId('685966dd8718115e852b332e'), 'Row_ID': 156, 'Order_ID': 'CA-2015-124919', 'Order_Date': '5/31/2015', 'Ship_Date': '6/2/2015', 'Ship_Mode': 'First Class', 'Customer_ID': 'SP-20650', 'Customer_Name': 'Stephanie Phelps', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Jose', 'State': 'California', 'Postal_Code': 95123, 'Region': 'West', 'Product_ID': 'OFF-ST-10001590', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Tenex Personal Project File with Scoop Front Design, Black', 'Sales': 80.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 21.0288}
# {'_id': ObjectId('685966dd8718115e852b332f'), 'Row_ID': 157, 'Order_ID': 'CA-2015-118948', 'Order_Date': '5/28/2015', 'Ship_Date': '6/3/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'NK-18490', 'Customer_Name': 'Neil Knudson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal_Code': 98105, 'Region': 'West', 'Product_ID': 'OFF-AR-10001547', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Newell 311', 'Sales': 6.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 1.7901}
# {'_id': ObjectId('685966dd8718115e852b3330'), 'Row_ID': 158, 'Order_ID': 'CA-2014-104269', 'Order_Date': '3/1/2014', 'Ship_Date': '3/6/2014', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DB-13060', 'Customer_Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal_Code': 98115, 'Region': 'West', 'Product_ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'SubCategory': 'Chairs', 'Product_Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 457.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 51.4764}
# {'_id': ObjectId('685966dd8718115e852b3333'), 'Row_ID': 161, 'Order_ID': 'CA-2016-162733', 'Order_Date': '5/11/2016', 'Ship_Date': '5/12/2016', 'Ship_Mode': 'First Class', 'Customer_ID': 'TT-21070', 'Customer_Name': 'Ted Trevino', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90045, 'Region': 'West', 'Product_ID': 'OFF-PA-10002751', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1920', 'Sales': 5.98, 'Quantity': 1, 'Discount': 0.0, 'Profit': 2.691}
# {'_id': ObjectId('685966dd8718115e852b3335'), 'Row_ID': 163, 'Order_ID': 'CA-2016-154508', 'Order_Date': '11/16/2016', 'Ship_Date': '11/20/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'RD-19900', 'Customer_Name': 'Ruben Dartt', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Carlsbad', 'State': 'New Mexico', 'Postal_Code': 88220, 'Region': 'West', 'Product_ID': 'OFF-EN-10001990', 'Category': 'Office Supplies', 'SubCategory': 'Envelopes', 'Product_Name': 'Staple envelope', 'Sales': 28.4, 'Quantity': 5, 'Discount': 0.0, 'Profit': 13.348}
# {'_id': ObjectId('685966dd8718115e852b3336'), 'Row_ID': 164, 'Order_ID': 'CA-2016-113817', 'Order_Date': '11/7/2016', 'Ship_Date': '11/11/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'MJ-17740', 'Customer_Name': 'Max Jones', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal_Code': 98115, 'Region': 'West', 'Product_ID': 'OFF-BI-10004002', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Wilson Jones International Size A4 Ring Binders', 'Sales': 27.68, 'Quantity': 2, 'Discount': 0.2, 'Profit': 9.688}
# {'_id': ObjectId('685966dd8718115e852b333e'), 'Row_ID': 172, 'Order_ID': 'CA-2014-118962', 'Order_Date': '8/5/2014', 'Ship_Date': '8/9/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'CS-12130', 'Customer_Name': 'Chad Sievert', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'OFF-PA-10000659', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6\x94 x 11\x94', 'Sales': 20.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 9.8418}
# {'_id': ObjectId('685966dd8718115e852b333f'), 'Row_ID': 173, 'Order_ID': 'CA-2014-118962', 'Order_Date': '8/5/2014', 'Ship_Date': '8/9/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'CS-12130', 'Customer_Name': 'Chad Sievert', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'OFF-PA-10001144', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1913', 'Sales': 110.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 53.2608}
# {'_id': ObjectId('685966dd8718115e852b3340'), 'Row_ID': 174, 'Order_ID': 'CA-2014-118962', 'Order_Date': '8/5/2014', 'Ship_Date': '8/9/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'CS-12130', 'Customer_Name': 'Chad Sievert', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'FUR-CH-10003817', 'Category': 'Furniture', 'SubCategory': 'Chairs', 'Product_Name': 'Global Value Steno Chair, Gray', 'Sales': 340.144, 'Quantity': 7, 'Discount': 0.2, 'Profit': 21.259}
# {'_id': ObjectId('685966dd8718115e852b334d'), 'Row_ID': 187, 'Order_ID': 'CA-2014-123260', 'Order_Date': '8/26/2014', 'Ship_Date': '8/30/2014', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'FM-14290', 'Customer_Name': 'Frank Merwin', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'TEC-AC-10002323', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'SanDisk Ultra 32 GB MicroSDHC Class 10 Memory Card', 'Sales': 176.8, 'Quantity': 8, 'Discount': 0.0, 'Profit': 22.984}
# {'_id': ObjectId('685966dd8718115e852b3355'), 'Row_ID': 195, 'Order_ID': 'CA-2015-131457', 'Order_Date': '10/31/2015', 'Ship_Date': '11/6/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'MZ-17515', 'Customer_Name': 'Mary Zewe', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Redlands', 'State': 'California', 'Postal_Code': 92374, 'Region': 'West', 'Product_ID': 'OFF-EN-10001509', 'Category': 'Office Supplies', 'SubCategory': 'Envelopes', 'Product_Name': 'Poly String Tie Envelopes', 'Sales': 14.28, 'Quantity': 7, 'Discount': 0.0, 'Profit': 6.7116}
# {'_id': ObjectId('685966dd8718115e852b335c'), 'Row_ID': 202, 'Order_ID': 'CA-2014-133690', 'Order_Date': '8/3/2014', 'Ship_Date': '8/5/2014', 'Ship_Mode': 'First Class', 'Customer_ID': 'BS-11755', 'Customer_Name': 'Bruce Stewart', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Denver', 'State': 'Colorado', 'Postal_Code': 80219, 'Region': 'West', 'Product_ID': 'FUR-TA-10004289', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables', 'Sales': 218.75, 'Quantity': 2, 'Discount': 0.5, 'Profit': -161.875}
# {'_id': ObjectId('685966dd8718115e852b335d'), 'Row_ID': 203, 'Order_ID': 'CA-2014-133690', 'Order_Date': '8/3/2014', 'Ship_Date': '8/5/2014', 'Ship_Mode': 'First Class', 'Customer_ID': 'BS-11755', 'Customer_Name': 'Bruce Stewart', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Denver', 'State': 'Colorado', 'Postal_Code': 80219, 'Region': 'West', 'Product_ID': 'OFF-AP-10003622', 'Category': 'Office Supplies', 'SubCategory': 'Appliances', 'Product_Name': 'Bravo II Megaboss 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack', 'Sales': 2.6, 'Quantity': 1, 'Discount': 0.2, 'Profit': 0.2925}
# {'_id': ObjectId('685966dd8718115e852b3360'), 'Row_ID': 206, 'Order_ID': 'CA-2017-108329', 'Order_Date': '12/9/2017', 'Ship_Date': '12/14/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'LE-16810', 'Customer_Name': 'Laurel Elliston', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Whittier', 'State': 'California', 'Postal_Code': 90604, 'Region': 'West', 'Product_ID': 'TEC-PH-10001918', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Nortel Business Series Terminal T7208 Digital phone', 'Sales': 444.768, 'Quantity': 4, 'Discount': 0.2, 'Profit': 44.4768}
# {'_id': ObjectId('685966dd8718115e852b336c'), 'Row_ID': 218, 'Order_ID': 'CA-2016-130162', 'Order_Date': '10/28/2016', 'Ship_Date': '11/1/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JH-15910', 'Customer_Name': 'Jonathan Howell', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-ST-10001328', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Personal Filing Tote with Lid, Black/Gray', 'Sales': 93.06, 'Quantity': 6, 'Discount': 0.0, 'Profit': 26.0568}
# {'_id': ObjectId('685966dd8718115e852b336d'), 'Row_ID': 219, 'Order_ID': 'CA-2016-130162', 'Order_Date': '10/28/2016', 'Ship_Date': '11/1/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JH-15910', 'Customer_Name': 'Jonathan Howell', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'TEC-PH-10002563', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Adtran 1202752G1', 'Sales': 302.376, 'Quantity': 3, 'Discount': 0.2, 'Profit': 22.6782}
# {'_id': ObjectId('685966dd8718115e852b337f'), 'Row_ID': 237, 'Order_ID': 'CA-2017-160514', 'Order_Date': '11/12/2017', 'Ship_Date': '11/16/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DB-13120', 'Customer_Name': 'David Bremer', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Santa Clara', 'State': 'California', 'Postal_Code': 95051, 'Region': 'West', 'Product_ID': 'OFF-PA-10002479', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)', 'Sales': 10.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 4.752}
# {'_id': ObjectId('685966dd8718115e852b338c'), 'Row_ID': 250, 'Order_ID': 'CA-2016-154739', 'Order_Date': '12/10/2016', 'Ship_Date': '12/15/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'LH-17155', 'Customer_Name': 'Logan Haushalter', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'FUR-CH-10002965', 'Category': 'Furniture', 'SubCategory': 'Chairs', 'Product_Name': 'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black', 'Sales': 321.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 28.1372}
# {'_id': ObjectId('685966dd8718115e852b338d'), 'Row_ID': 251, 'Order_ID': 'CA-2016-145625', 'Order_Date': '9/11/2016', 'Ship_Date': '9/17/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KC-16540', 'Customer_Name': 'Kelly Collister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal_Code': 92037, 'Region': 'West', 'Product_ID': 'OFF-PA-10004569', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Wirebound Message Books, Two 4 1/4" x 5" Forms per Page', 'Sales': 7.61, 'Quantity': 1, 'Discount': 0.0, 'Profit': 3.5767}
# {'_id': ObjectId('685966dd8718115e852b338e'), 'Row_ID': 252, 'Order_ID': 'CA-2016-145625', 'Order_Date': '9/11/2016', 'Ship_Date': '9/17/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KC-16540', 'Customer_Name': 'Kelly Collister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal_Code': 92037, 'Region': 'West', 'Product_ID': 'TEC-AC-10003832', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Logitech\xa0P710e Mobile Speakerphone', 'Sales': 3347.37, 'Quantity': 13, 'Discount': 0.0, 'Profit': 636.0003}
# {'_id': ObjectId('685966dd8718115e852b339c'), 'Row_ID': 266, 'Order_ID': 'CA-2015-155040', 'Order_Date': '11/10/2015', 'Ship_Date': '11/15/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AH-10210', 'Customer_Name': 'Alan Hwang', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Brentwood', 'State': 'California', 'Postal_Code': 94513, 'Region': 'West', 'Product_ID': 'TEC-AC-10004469', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Microsoft Sculpt Comfort Mouse', 'Sales': 79.9, 'Quantity': 2, 'Discount': 0.0, 'Profit': 35.156}
# {'_id': ObjectId('685966dd8718115e852b33a1'), 'Row_ID': 271, 'Order_ID': 'CA-2017-163979', 'Order_Date': '12/28/2017', 'Ship_Date': '1/2/2018', 'Ship_Mode': 'Second Class', 'Customer_ID': 'KH-16690', 'Customer_Name': 'Kristen Hastings', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94110, 'Region': 'West', 'Product_ID': 'OFF-ST-10003208', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Adjustable Depth Letter/Legal Cart', 'Sales': 725.84, 'Quantity': 4, 'Discount': 0.0, 'Profit': 210.4936}
# {'_id': ObjectId('685966dd8718115e852b33a2'), 'Row_ID': 272, 'Order_ID': 'CA-2015-155334', 'Order_Date': '7/30/2015', 'Ship_Date': '7/31/2015', 'Ship_Mode': 'First Class', 'Customer_ID': 'HA-14920', 'Customer_Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'TEC-AC-10003628', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Logitech 910-002974 M325 Wireless Mouse for Web Scrolling', 'Sales': 209.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 92.3692}
# {'_id': ObjectId('685966dd8718115e852b33a3'), 'Row_ID': 273, 'Order_ID': 'CA-2015-155334', 'Order_Date': '7/30/2015', 'Ship_Date': '7/31/2015', 'Ship_Mode': 'First Class', 'Customer_ID': 'HA-14920', 'Customer_Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'FUR-FU-10003274', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Regeneration Desk Collection', 'Sales': 5.28, 'Quantity': 3, 'Discount': 0.0, 'Profit': 2.3232}
# {'_id': ObjectId('685966dd8718115e852b33a4'), 'Row_ID': 274, 'Order_ID': 'CA-2015-155334', 'Order_Date': '7/30/2015', 'Ship_Date': '7/31/2015', 'Ship_Mode': 'First Class', 'Customer_ID': 'HA-14920', 'Customer_Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94109, 'Region': 'West', 'Product_ID': 'OFF-BI-10002557', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Presstex Flexible Ring Binders', 'Sales': 10.92, 'Quantity': 3, 'Discount': 0.2, 'Profit': 4.095}
# {'_id': ObjectId('685966dd8718115e852b33a5'), 'Row_ID': 275, 'Order_ID': 'CA-2017-118136', 'Order_Date': '9/16/2017', 'Ship_Date': '9/17/2017', 'Ship_Mode': 'First Class', 'Customer_ID': 'BB-10990', 'Customer_Name': 'Barry Blumstein', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Inglewood', 'State': 'California', 'Postal_Code': 90301, 'Region': 'West', 'Product_ID': 'OFF-PA-10002615', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Ampad Gold Fibre Wirebound Steno Books, 6" x 9", Gregg Ruled', 'Sales': 8.82, 'Quantity': 2, 'Discount': 0.0, 'Profit': 4.0572}
# {'_id': ObjectId('685966dd8718115e852b33a6'), 'Row_ID': 276, 'Order_ID': 'CA-2017-118136', 'Order_Date': '9/16/2017', 'Ship_Date': '9/17/2017', 'Ship_Mode': 'First Class', 'Customer_ID': 'BB-10990', 'Customer_Name': 'Barry Blumstein', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Inglewood', 'State': 'California', 'Postal_Code': 90301, 'Region': 'West', 'Product_ID': 'OFF-AR-10001427', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Newell 330', 'Sales': 5.98, 'Quantity': 1, 'Discount': 0.0, 'Profit': 1.5548}
# {'_id': ObjectId('685966dd8718115e852b33ad'), 'Row_ID': 283, 'Order_ID': 'CA-2015-130890', 'Order_Date': '11/2/2015', 'Ship_Date': '11/6/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JO-15280', 'Customer_Name': "Jas O'Carroll", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90004, 'Region': 'West', 'Product_ID': 'FUR-TA-10002903', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Bevis Round Bullnose 29" High Table Top', 'Sales': 1038.84, 'Quantity': 5, 'Discount': 0.2, 'Profit': 51.942}
# {'_id': ObjectId('685966dd8718115e852b33ae'), 'Row_ID': 284, 'Order_ID': 'CA-2015-130883', 'Order_Date': '9/26/2015', 'Ship_Date': '10/2/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'TB-21520', 'Customer_Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal_Code': 97206, 'Region': 'West', 'Product_ID': 'OFF-PA-10000474', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Easy-staple paper', 'Sales': 141.76, 'Quantity': 5, 'Discount': 0.2, 'Profit': 47.844}
# ...
# {'_id': ObjectId('685966dd8718115e852b595b'), 'Row_ID': 9929, 'Order_ID': 'CA-2016-129630', 'Order_Date': '9/4/2016', 'Ship_Date': '9/4/2016', 'Ship_Mode': 'Same Day', 'Customer_ID': 'IM-15055', 'Customer_Name': 'Ionia McGrath', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'FUR-FU-10000260', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': '6" Cubicle Wall Clock, Black', 'Sales': 24.27, 'Quantity': 3, 'Discount': 0.0, 'Profit': 8.7372}
# {'_id': ObjectId('685966dd8718115e852b595c'), 'Row_ID': 9930, 'Order_ID': 'CA-2016-129630', 'Order_Date': '9/4/2016', 'Ship_Date': '9/4/2016', 'Ship_Mode': 'Same Day', 'Customer_ID': 'IM-15055', 'Customer_Name': 'Ionia McGrath', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'TEC-CO-10003763', 'Category': 'Technology', 'SubCategory': 'Copiers', 'Product_Name': 'Canon PC1060 Personal Laser Copier', 'Sales': 2799.96, 'Quantity': 5, 'Discount': 0.2, 'Profit': 944.9865}
# {'_id': ObjectId('685966dd8718115e852b595d'), 'Row_ID': 9931, 'Order_ID': 'CA-2015-104948', 'Order_Date': '11/13/2015', 'Ship_Date': '11/17/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KH-16510', 'Customer_Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Bernardino', 'State': 'California', 'Postal_Code': 92404, 'Region': 'West', 'Product_ID': 'OFF-BI-10001267', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Universal Recycled Hanging Pressboard Report Binders, Letter Size', 'Sales': 9.872, 'Quantity': 2, 'Discount': 0.2, 'Profit': 3.4552}
# {'_id': ObjectId('685966dd8718115e852b595e'), 'Row_ID': 9932, 'Order_ID': 'CA-2015-104948', 'Order_Date': '11/13/2015', 'Ship_Date': '11/17/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KH-16510', 'Customer_Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Bernardino', 'State': 'California', 'Postal_Code': 92404, 'Region': 'West', 'Product_ID': 'FUR-BO-10004357', 'Category': 'Furniture', 'SubCategory': 'Bookcases', 'Product_Name': "O'Sullivan Living Dimensions 3-Shelf Bookcases", 'Sales': 683.332, 'Quantity': 4, 'Discount': 0.15, 'Profit': -40.196}
# {'_id': ObjectId('685966dd8718115e852b595f'), 'Row_ID': 9933, 'Order_ID': 'CA-2015-104948', 'Order_Date': '11/13/2015', 'Ship_Date': '11/17/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'KH-16510', 'Customer_Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Bernardino', 'State': 'California', 'Postal_Code': 92404, 'Region': 'West', 'Product_ID': 'OFF-PA-10004610', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1900', 'Sales': 29.96, 'Quantity': 7, 'Discount': 0.0, 'Profit': 13.482}
# {'_id': ObjectId('685966dd8718115e852b5964'), 'Row_ID': 9938, 'Order_ID': 'CA-2016-164889', 'Order_Date': '6/3/2016', 'Ship_Date': '6/6/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'CP-12340', 'Customer_Name': 'Christine Phan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90049, 'Region': 'West', 'Product_ID': 'FUR-TA-10001676', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Hon 61000 Series Interactive Training Tables', 'Sales': 71.088, 'Quantity': 2, 'Discount': 0.2, 'Profit': -1.7772}
# {'_id': ObjectId('685966dd8718115e852b5968'), 'Row_ID': 9942, 'Order_ID': 'CA-2017-164028', 'Order_Date': '11/24/2017', 'Ship_Date': '11/30/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'JL-15835', 'Customer_Name': 'John Lee', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal_Code': 94122, 'Region': 'West', 'Product_ID': 'TEC-AC-10001772', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Memorex Mini Travel Drive 16 GB USB 2.0 Flash Drive', 'Sales': 223.58, 'Quantity': 14, 'Discount': 0.0, 'Profit': 87.1962}
# {'_id': ObjectId('685966dd8718115e852b5969'), 'Row_ID': 9943, 'Order_ID': 'CA-2014-143371', 'Order_Date': '12/28/2014', 'Ship_Date': '1/3/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'MD-17350', 'Customer_Name': 'Maribeth Dona', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Anaheim', 'State': 'California', 'Postal_Code': 92804, 'Region': 'West', 'Product_ID': 'OFF-ST-10001128', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Carina Mini System Audio Rack, Model AR050B', 'Sales': 998.82, 'Quantity': 9, 'Discount': 0.0, 'Profit': 29.9646}
# {'_id': ObjectId('685966dd8718115e852b596a'), 'Row_ID': 9944, 'Order_ID': 'CA-2014-143371', 'Order_Date': '12/28/2014', 'Ship_Date': '1/3/2015', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'MD-17350', 'Customer_Name': 'Maribeth Dona', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Anaheim', 'State': 'California', 'Postal_Code': 92804, 'Region': 'West', 'Product_ID': 'OFF-SU-10002537', 'Category': 'Office Supplies', 'SubCategory': 'Supplies', 'Product_Name': 'Acme Box Cutter Scissors', 'Sales': 51.15, 'Quantity': 5, 'Discount': 0.0, 'Profit': 13.299}
# {'_id': ObjectId('685966dd8718115e852b596b'), 'Row_ID': 9945, 'Order_ID': 'CA-2015-145415', 'Order_Date': '4/12/2015', 'Ship_Date': '4/17/2015', 'Ship_Mode': 'Second Class', 'Customer_ID': 'RD-19660', 'Customer_Name': 'Robert Dilbeck', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal_Code': 98103, 'Region': 'West', 'Product_ID': 'OFF-ST-10000419', 'Category': 'Office Supplies', 'SubCategory': 'Storage', 'Product_Name': 'Rogers Jumbo File, Granite', 'Sales': 40.74, 'Quantity': 3, 'Discount': 0.0, 'Profit': 0.4074}
# {'_id': ObjectId('685966dd8718115e852b5973'), 'Row_ID': 9953, 'Order_ID': 'CA-2015-141593', 'Order_Date': '12/14/2015', 'Ship_Date': '12/16/2015', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DB-12970', 'Customer_Name': 'Darren Budd', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90045, 'Region': 'West', 'Product_ID': 'OFF-BI-10001153', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Ibico Recycled Grain-Textured Covers', 'Sales': 55.264, 'Quantity': 2, 'Discount': 0.2, 'Profit': 20.724}
# {'_id': ObjectId('685966dd8718115e852b5974'), 'Row_ID': 9954, 'Order_ID': 'CA-2015-141593', 'Order_Date': '12/14/2015', 'Ship_Date': '12/16/2015', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DB-12970', 'Customer_Name': 'Darren Budd', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90045, 'Region': 'West', 'Product_ID': 'OFF-PA-10004983', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 23', 'Sales': 6.48, 'Quantity': 1, 'Discount': 0.0, 'Profit': 3.1104}
# {'_id': ObjectId('685966dd8718115e852b5975'), 'Row_ID': 9955, 'Order_ID': 'CA-2015-141593', 'Order_Date': '12/14/2015', 'Ship_Date': '12/16/2015', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DB-12970', 'Customer_Name': 'Darren Budd', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90045, 'Region': 'West', 'Product_ID': 'OFF-BI-10000948', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'GBC Laser Imprintable Binding System Covers, Desert Sand', 'Sales': 34.248, 'Quantity': 3, 'Discount': 0.2, 'Profit': 11.5587}
# {'_id': ObjectId('685966dd8718115e852b5976'), 'Row_ID': 9956, 'Order_ID': 'CA-2015-141593', 'Order_Date': '12/14/2015', 'Ship_Date': '12/16/2015', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DB-12970', 'Customer_Name': 'Darren Budd', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90045, 'Region': 'West', 'Product_ID': 'FUR-TA-10002622', 'Category': 'Furniture', 'SubCategory': 'Tables', 'Product_Name': 'Bush Andora Conference Table, Maple/Graphite Gray Finish', 'Sales': 273.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 10.2588}
# {'_id': ObjectId('685966dd8718115e852b597a'), 'Row_ID': 9960, 'Order_ID': 'CA-2017-137421', 'Order_Date': '10/6/2017', 'Ship_Date': '10/11/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AJ-10945', 'Customer_Name': 'Ashley Jarboe', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Chandler', 'State': 'Arizona', 'Postal_Code': 85224, 'Region': 'West', 'Product_ID': 'OFF-AR-10001761', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Avery Hi-Liter Smear-Safe Highlighters', 'Sales': 9.344, 'Quantity': 2, 'Discount': 0.2, 'Profit': 1.8688}
# {'_id': ObjectId('685966dd8718115e852b5988'), 'Row_ID': 9974, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'TEC-PH-10004080', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Avaya 5410 Digital phone', 'Sales': 271.96, 'Quantity': 5, 'Discount': 0.2, 'Profit': 27.196}
# {'_id': ObjectId('685966dd8718115e852b5989'), 'Row_ID': 9975, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-AR-10004752', 'Category': 'Office Supplies', 'SubCategory': 'Art', 'Product_Name': 'Blackstonian Pencils', 'Sales': 18.69, 'Quantity': 7, 'Discount': 0.0, 'Profit': 5.2332}
# {'_id': ObjectId('685966dd8718115e852b598a'), 'Row_ID': 9976, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-PA-10000743', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'Xerox 1977', 'Sales': 13.36, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.4128}
# {'_id': ObjectId('685966dd8718115e852b598b'), 'Row_ID': 9977, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'TEC-PH-10002496', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Cisco SPA301', 'Sales': 249.584, 'Quantity': 2, 'Discount': 0.2, 'Profit': 31.198}
# {'_id': ObjectId('685966dd8718115e852b598c'), 'Row_ID': 9978, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-FA-10003467', 'Category': 'Office Supplies', 'SubCategory': 'Fasteners', 'Product_Name': 'Alliance Big Bands Rubber Bands, 12/Pack', 'Sales': 13.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 0.0}
# {'_id': ObjectId('685966dd8718115e852b598d'), 'Row_ID': 9979, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-BI-10003727', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Avery Durable Slant Ring Binders With Label Holder', 'Sales': 13.376, 'Quantity': 4, 'Discount': 0.2, 'Profit': 4.6816}
# {'_id': ObjectId('685966dd8718115e852b598e'), 'Row_ID': 9980, 'Order_ID': 'US-2016-103674', 'Order_Date': '12/6/2016', 'Ship_Date': '12/10/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'AP-10720', 'Customer_Name': 'Anne Pryor', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90032, 'Region': 'West', 'Product_ID': 'OFF-BI-10002026', 'Category': 'Office Supplies', 'SubCategory': 'Binders', 'Product_Name': 'Ibico Recycled Linen-Style Covers', 'Sales': 437.472, 'Quantity': 14, 'Discount': 0.2, 'Profit': 153.1152}
# {'_id': ObjectId('685966dd8718115e852b5995'), 'Row_ID': 9987, 'Order_ID': 'CA-2016-125794', 'Order_Date': '9/29/2016', 'Ship_Date': '10/3/2016', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'ML-17410', 'Customer_Name': 'Maris LaWare', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90008, 'Region': 'West', 'Product_ID': 'TEC-AC-10003399', 'Category': 'Technology', 'SubCategory': 'Accessories', 'Product_Name': 'Memorex Mini Travel Drive 64 GB USB 2.0 Flash Drive', 'Sales': 36.24, 'Quantity': 1, 'Discount': 0.0, 'Profit': 15.2208}
# {'_id': ObjectId('685966dd8718115e852b5999'), 'Row_ID': 9991, 'Order_ID': 'CA-2017-121258', 'Order_Date': '2/26/2017', 'Ship_Date': '3/3/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DB-13060', 'Customer_Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Costa Mesa', 'State': 'California', 'Postal_Code': 92627, 'Region': 'West', 'Product_ID': 'FUR-FU-10000747', 'Category': 'Furniture', 'SubCategory': 'Furnishings', 'Product_Name': 'Tenex B1-RE Series Chair Mats for Low Pile Carpets', 'Sales': 91.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 15.6332}
# {'_id': ObjectId('685966dd8718115e852b599a'), 'Row_ID': 9992, 'Order_ID': 'CA-2017-121258', 'Order_Date': '2/26/2017', 'Ship_Date': '3/3/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DB-13060', 'Customer_Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Costa Mesa', 'State': 'California', 'Postal_Code': 92627, 'Region': 'West', 'Product_ID': 'TEC-PH-10003645', 'Category': 'Technology', 'SubCategory': 'Phones', 'Product_Name': 'Aastra 57i VoIP phone', 'Sales': 258.576, 'Quantity': 2, 'Discount': 0.2, 'Profit': 19.3932}
# {'_id': ObjectId('685966dd8718115e852b599b'), 'Row_ID': 9993, 'Order_ID': 'CA-2017-121258', 'Order_Date': '2/26/2017', 'Ship_Date': '3/3/2017', 'Ship_Mode': 'Standard Class', 'Customer_ID': 'DB-13060', 'Customer_Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Costa Mesa', 'State': 'California', 'Postal_Code': 92627, 'Region': 'West', 'Product_ID': 'OFF-PA-10004041', 'Category': 'Office Supplies', 'SubCategory': 'Paper', 'Product_Name': 'It\'s Hot Message Books with Stickers, 2 3/4" x 5"', 'Sales': 29.6, 'Quantity': 4, 'Discount': 0.0, 'Profit': 13.32}
# {'_id': ObjectId('685966dd8718115e852b599c'), 'Row_ID': 9994, 'Order_ID': 'CA-2017-119914', 'Order_Date': '5/4/2017', 'Ship_Date': '5/9/2017', 'Ship_Mode': 'Second Class', 'Customer_ID': 'CC-12220', 'Customer_Name': 'Chris Cortes', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Westminster', 'State': 'California', 'Postal_Code': 92683, 'Region': 'West', 'Product_ID': 'OFF-AP-10002684', 'Category': 'Office Supplies', 'SubCategory': 'Appliances', 'Product_Name': 'Acco 7-Outlet Masterpiece Power Center, Wihtout Fax/Phone Line Protection', 'Sales': 243.16, 'Quantity': 2, 'Discount': 0.0, 'Profit': 72.948}

# %%
###5. Write a query to find orders where Sales is greater than 500

orders = collections.find({'Sales':{'$gt':500}},{'Order_ID','Sales'})
for order in orders:
  print(order)
# Out:
# {'_id': ObjectId('685966dd8718115e852b3294'), 'Order_ID': 'CA-2016-152156', 'Sales': 731.94}
# {'_id': ObjectId('685966dd8718115e852b3296'), 'Order_ID': 'US-2015-108966', 'Sales': 957.5775}
# {'_id': ObjectId('685966dd8718115e852b329a'), 'Order_ID': 'CA-2014-115812', 'Sales': 907.152}
# {'_id': ObjectId('685966dd8718115e852b329d'), 'Order_ID': 'CA-2014-115812', 'Sales': 1706.184}
# {'_id': ObjectId('685966dd8718115e852b329e'), 'Order_ID': 'CA-2014-115812', 'Sales': 911.424}
# {'_id': ObjectId('685966dd8718115e852b32a3'), 'Order_ID': 'CA-2014-105893', 'Sales': 665.88}
# {'_id': ObjectId('685966dd8718115e852b32ab'), 'Order_ID': 'CA-2015-106320', 'Sales': 1044.63}
# {'_id': ObjectId('685966dd8718115e852b32ae'), 'Order_ID': 'US-2015-150630', 'Sales': 3083.43}
# {'_id': ObjectId('685966dd8718115e852b32b6'), 'Order_ID': 'CA-2016-117590', 'Sales': 1097.544}
# {'_id': ObjectId('685966dd8718115e852b32b9'), 'Order_ID': 'CA-2015-117415', 'Sales': 532.3992}
# {'_id': ObjectId('685966dd8718115e852b32c9'), 'Order_ID': 'CA-2016-105816', 'Sales': 1029.95}
# {'_id': ObjectId('685966dd8718115e852b32d6'), 'Order_ID': 'CA-2014-106376', 'Sales': 1113.024}
# {'_id': ObjectId('685966dd8718115e852b32db'), 'Order_ID': 'US-2015-134026', 'Sales': 831.936}
# {'_id': ObjectId('685966dd8718115e852b3308'), 'Order_ID': 'CA-2015-110457', 'Sales': 787.53}
# {'_id': ObjectId('685966dd8718115e852b330f'), 'Order_ID': 'US-2014-152030', 'Sales': 600.558}
# {'_id': ObjectId('685966dd8718115e852b3310'), 'Order_ID': 'US-2014-134614', 'Sales': 617.7}
# {'_id': ObjectId('685966dd8718115e852b3323'), 'Order_ID': 'CA-2017-155376', 'Sales': 839.43}
# {'_id': ObjectId('685966dd8718115e852b3324'), 'Order_ID': 'CA-2015-110744', 'Sales': 671.93}
# {'_id': ObjectId('685966dd8718115e852b3328'), 'Order_ID': 'CA-2016-114489', 'Sales': 1951.84}
# {'_id': ObjectId('685966dd8718115e852b3332'), 'Order_ID': 'CA-2016-114104', 'Sales': 944.93}
# {'_id': ObjectId('685966dd8718115e852b3338'), 'Order_ID': 'CA-2014-139892', 'Sales': 8159.952}
# {'_id': ObjectId('685966dd8718115e852b333a'), 'Order_ID': 'CA-2014-139892', 'Sales': 1740.06}
# {'_id': ObjectId('685966dd8718115e852b3349'), 'Order_ID': 'CA-2014-158274', 'Sales': 503.96}
# {'_id': ObjectId('685966dd8718115e852b3350'), 'Order_ID': 'CA-2015-102281', 'Sales': 899.136}
# {'_id': ObjectId('685966dd8718115e852b3353'), 'Order_ID': 'CA-2015-102281', 'Sales': 626.352}
# {'_id': ObjectId('685966dd8718115e852b336a'), 'Order_ID': 'CA-2015-146262', 'Sales': 1188.0}
# {'_id': ObjectId('685966dd8718115e852b3375'), 'Order_ID': 'CA-2015-163055', 'Sales': 622.45}
# {'_id': ObjectId('685966dd8718115e852b337b'), 'Order_ID': 'US-2017-100930', 'Sales': 620.6145}
# {'_id': ObjectId('685966dd8718115e852b337e'), 'Order_ID': 'US-2017-100930', 'Sales': 617.976}
# {'_id': ObjectId('685966dd8718115e852b3387'), 'Order_ID': 'CA-2014-131926', 'Sales': 2001.86}
# {'_id': ObjectId('685966dd8718115e852b338a'), 'Order_ID': 'CA-2014-131926', 'Sales': 1503.25}
# {'_id': ObjectId('685966dd8718115e852b338e'), 'Order_ID': 'CA-2016-145625', 'Sales': 3347.37}
# {'_id': ObjectId('685966dd8718115e852b3394'), 'Order_ID': 'US-2015-159982', 'Sales': 647.904}
# {'_id': ObjectId('685966dd8718115e852b3399'), 'Order_ID': 'US-2014-106992', 'Sales': 3059.982}
# {'_id': ObjectId('685966dd8718115e852b339a'), 'Order_ID': 'US-2014-106992', 'Sales': 2519.958}
# {'_id': ObjectId('685966dd8718115e852b33a1'), 'Order_ID': 'CA-2017-163979', 'Sales': 725.84}
# {'_id': ObjectId('685966dd8718115e852b33ac'), 'Order_ID': 'US-2015-161991', 'Sales': 1114.4}
# {'_id': ObjectId('685966dd8718115e852b33ad'), 'Order_ID': 'CA-2015-130890', 'Sales': 1038.84}
# {'_id': ObjectId('685966dd8718115e852b33b3'), 'Order_ID': 'CA-2016-112697', 'Sales': 961.48}
# {'_id': ObjectId('685966dd8718115e852b33be'), 'Order_ID': 'CA-2016-142545', 'Sales': 1082.48}
# {'_id': ObjectId('685966dd8718115e852b33d1'), 'Order_ID': 'CA-2014-164973', 'Sales': 3991.98}
# {'_id': ObjectId('685966dd8718115e852b33db'), 'Order_ID': 'US-2016-141544', 'Sales': 786.744}
# {'_id': ObjectId('685966dd8718115e852b33e2'), 'Order_ID': 'CA-2015-137946', 'Sales': 959.984}
# {'_id': ObjectId('685966dd8718115e852b33e5'), 'Order_ID': 'CA-2014-129924', 'Sales': 698.352}
# {'_id': ObjectId('685966dd8718115e852b33e8'), 'Order_ID': 'CA-2014-122336', 'Sales': 509.97}
# {'_id': ObjectId('685966dd8718115e852b33f4'), 'Order_ID': 'CA-2016-129714', 'Sales': 4355.168}
# {'_id': ObjectId('685966dd8718115e852b33fa'), 'Order_ID': 'CA-2017-155698', 'Sales': 647.84}
# {'_id': ObjectId('685966dd8718115e852b3404'), 'Order_ID': 'CA-2016-155516', 'Sales': 1043.92}
# {'_id': ObjectId('685966dd8718115e852b3408'), 'Order_ID': 'US-2014-119137', 'Sales': 1023.936}
# {'_id': ObjectId('685966dd8718115e852b340c'), 'Order_ID': 'US-2017-134481', 'Sales': 1488.424}
# {'_id': ObjectId('685966dd8718115e852b341b'), 'Order_ID': 'US-2014-135972', 'Sales': 1799.97}
# {'_id': ObjectId('685966dd8718115e852b3422'), 'Order_ID': 'CA-2016-108987', 'Sales': 2396.2656}
# {'_id': ObjectId('685966dd8718115e852b3429'), 'Order_ID': 'CA-2017-117457', 'Sales': 1199.976}
# {'_id': ObjectId('685966dd8718115e852b342b'), 'Order_ID': 'CA-2017-117457', 'Sales': 1004.024}
# {'_id': ObjectId('685966dd8718115e852b342f'), 'Order_ID': 'CA-2017-117457', 'Sales': 1336.829}
# {'_id': ObjectId('685966dd8718115e852b343b'), 'Order_ID': 'CA-2017-155705', 'Sales': 866.4}
# {'_id': ObjectId('685966dd8718115e852b3444'), 'Order_ID': 'CA-2016-127369', 'Sales': 714.3}
# {'_id': ObjectId('685966dd8718115e852b3447'), 'Order_ID': 'CA-2016-147375', 'Sales': 1007.979}
# {'_id': ObjectId('685966dd8718115e852b3459'), 'Order_ID': 'CA-2017-147277', 'Sales': 665.408}
# {'_id': ObjectId('685966dd8718115e852b345c'), 'Order_ID': 'US-2016-157945', 'Sales': 747.558}
# {'_id': ObjectId('685966dd8718115e852b345f'), 'Order_ID': 'CA-2015-109638', 'Sales': 899.91}
# {'_id': ObjectId('685966dd8718115e852b3462'), 'Order_ID': 'CA-2016-109869', 'Sales': 1272.63}
# {'_id': ObjectId('685966dd8718115e852b346c'), 'Order_ID': 'CA-2014-144666', 'Sales': 703.968}
# {'_id': ObjectId('685966dd8718115e852b3473'), 'Order_ID': 'CA-2016-100790', 'Sales': 704.25}
# {'_id': ObjectId('685966dd8718115e852b3478'), 'Order_ID': 'CA-2017-140963', 'Sales': 514.165}
# {'_id': ObjectId('685966dd8718115e852b347a'), 'Order_ID': 'CA-2014-154627', 'Sales': 2735.952}
# {'_id': ObjectId('685966dd8718115e852b3489'), 'Order_ID': 'US-2016-105578', 'Sales': 801.568}
# {'_id': ObjectId('685966dd8718115e852b3490'), 'Order_ID': 'CA-2015-145352', 'Sales': 6354.95}
# {'_id': ObjectId('685966dd8718115e852b3496'), 'Order_ID': 'CA-2017-127432', 'Sales': 2999.95}
# {'_id': ObjectId('685966dd8718115e852b3499'), 'Order_ID': 'CA-2017-127432', 'Sales': 1126.02}
# {'_id': ObjectId('685966dd8718115e852b34a1'), 'Order_ID': 'CA-2017-113558', 'Sales': 683.952}
# {'_id': ObjectId('685966dd8718115e852b34a4'), 'Order_ID': 'US-2015-138303', 'Sales': 666.248}
# {'_id': ObjectId('685966dd8718115e852b34a8'), 'Order_ID': 'CA-2016-168753', 'Sales': 979.95}
# {'_id': ObjectId('685966dd8718115e852b34b1'), 'Order_ID': 'US-2015-120161', 'Sales': 646.776}
# {'_id': ObjectId('685966dd8718115e852b34ba'), 'Order_ID': 'CA-2016-136406', 'Sales': 1121.568}
# {'_id': ObjectId('685966dd8718115e852b34bd'), 'Order_ID': 'CA-2017-100650', 'Sales': 1295.78}
# {'_id': ObjectId('685966dd8718115e852b34c0'), 'Order_ID': 'CA-2016-113243', 'Sales': 1335.68}
# {'_id': ObjectId('685966dd8718115e852b34e6'), 'Order_ID': 'CA-2014-131450', 'Sales': 1199.976}
# {'_id': ObjectId('685966dd8718115e852b34f8'), 'Order_ID': 'CA-2016-121223', 'Sales': 728.946}
# {'_id': ObjectId('685966dd8718115e852b3502'), 'Order_ID': 'CA-2015-138009', 'Sales': 555.21}
# {'_id': ObjectId('685966dd8718115e852b3503'), 'Order_ID': 'CA-2015-138009', 'Sales': 523.48}
# {'_id': ObjectId('685966dd8718115e852b3511'), 'Order_ID': 'CA-2016-115917', 'Sales': 1049.2}
# {'_id': ObjectId('685966dd8718115e852b3524'), 'Order_ID': 'US-2016-156097', 'Sales': 701.372}
# {'_id': ObjectId('685966dd8718115e852b3526'), 'Order_ID': 'CA-2015-146563', 'Sales': 999.432}
# {'_id': ObjectId('685966dd8718115e852b3527'), 'Order_ID': 'CA-2015-146563', 'Sales': 724.08}
# {'_id': ObjectId('685966dd8718115e852b3528'), 'Order_ID': 'CA-2015-146563', 'Sales': 918.785}
# {'_id': ObjectId('685966dd8718115e852b353e'), 'Order_ID': 'US-2017-168116', 'Sales': 7999.98}
# {'_id': ObjectId('685966dd8718115e852b3557'), 'Order_ID': 'CA-2014-112158', 'Sales': 883.92}
# {'_id': ObjectId('685966dd8718115e852b3564'), 'Order_ID': 'CA-2016-142335', 'Sales': 1652.94}
# {'_id': ObjectId('685966dd8718115e852b356d'), 'Order_ID': 'US-2016-150861', 'Sales': 542.646}
# {'_id': ObjectId('685966dd8718115e852b357d'), 'Order_ID': 'CA-2014-124429', 'Sales': 567.12}
# {'_id': ObjectId('685966dd8718115e852b3584'), 'Order_ID': 'CA-2016-110499', 'Sales': 1199.976}
# {'_id': ObjectId('685966dd8718115e852b3590'), 'Order_ID': 'CA-2014-162775', 'Sales': 646.74}
# {'_id': ObjectId('685966dd8718115e852b3592'), 'Order_ID': 'CA-2014-162775', 'Sales': 572.58}
# {'_id': ObjectId('685966dd8718115e852b3594'), 'Order_ID': 'CA-2016-157245', 'Sales': 641.96}
# {'_id': ObjectId('685966dd8718115e852b359c'), 'Order_ID': 'CA-2015-144267', 'Sales': 544.008}
# {'_id': ObjectId('685966dd8718115e852b35ab'), 'Order_ID': 'CA-2016-105256', 'Sales': 1363.96}
# {'_id': ObjectId('685966dd8718115e852b35b9'), 'Order_ID': 'CA-2014-134313', 'Sales': 1983.968}
# {'_id': ObjectId('685966dd8718115e852b35bd'), 'Order_ID': 'CA-2014-151995', 'Sales': 1298.55}
# {'_id': ObjectId('685966dd8718115e852b35c1'), 'Order_ID': 'CA-2017-143686', 'Sales': 1399.93}
# {'_id': ObjectId('685966dd8718115e852b35c6'), 'Order_ID': 'CA-2014-140858', 'Sales': 1228.465}
# {'_id': ObjectId('685966dd8718115e852b35f8'), 'Order_ID': 'CA-2016-158099', 'Sales': 1141.47}
# {'_id': ObjectId('685966dd8718115e852b3603'), 'Order_ID': 'CA-2017-111689', 'Sales': 1242.9}
# {'_id': ObjectId('685966dd8718115e852b3610'), 'Order_ID': 'CA-2017-133256', 'Sales': 543.92}
# {'_id': ObjectId('685966dd8718115e852b3620'), 'Order_ID': 'CA-2017-137596', 'Sales': 1199.8}
# {'_id': ObjectId('685966dd8718115e852b3621'), 'Order_ID': 'CA-2017-137596', 'Sales': 1928.78}
# {'_id': ObjectId('685966dd8718115e852b3627'), 'Order_ID': 'US-2014-141215', 'Sales': 797.944}
# {'_id': ObjectId('685966dd8718115e852b362f'), 'Order_ID': 'CA-2016-149797', 'Sales': 841.568}
# {'_id': ObjectId('685966dd8718115e852b3641'), 'Order_ID': 'CA-2016-142958', 'Sales': 1114.272}
# {'_id': ObjectId('685966dd8718115e852b3643'), 'Order_ID': 'CA-2015-120880', 'Sales': 540.57}
# {'_id': ObjectId('685966dd8718115e852b3646'), 'Order_ID': 'US-2017-110576', 'Sales': 516.488}
# {'_id': ObjectId('685966dd8718115e852b3647'), 'Order_ID': 'US-2017-110576', 'Sales': 1007.232}
# {'_id': ObjectId('685966dd8718115e852b3648'), 'Order_ID': 'US-2017-110576', 'Sales': 2065.32}
# {'_id': ObjectId('685966dd8718115e852b365c'), 'Order_ID': 'CA-2017-135279', 'Sales': 501.81}
# {'_id': ObjectId('685966dd8718115e852b3664'), 'Order_ID': 'CA-2017-159366', 'Sales': 3059.982}
# {'_id': ObjectId('685966dd8718115e852b3667'), 'Order_ID': 'CA-2016-144939', 'Sales': 599.292}
# {'_id': ObjectId('685966dd8718115e852b3669'), 'Order_ID': 'CA-2014-163419', 'Sales': 559.984}
# {'_id': ObjectId('685966dd8718115e852b366a'), 'Order_ID': 'CA-2014-163419', 'Sales': 603.92}
# {'_id': ObjectId('685966dd8718115e852b366f'), 'Order_ID': 'CA-2017-167899', 'Sales': 520.05}
# {'_id': ObjectId('685966dd8718115e852b3671'), 'Order_ID': 'CA-2015-153549', 'Sales': 1166.92}
# {'_id': ObjectId('685966dd8718115e852b3675'), 'Order_ID': 'CA-2014-117639', 'Sales': 2715.93}
# {'_id': ObjectId('685966dd8718115e852b3676'), 'Order_ID': 'CA-2014-117639', 'Sales': 617.97}
# {'_id': ObjectId('685966dd8718115e852b367c'), 'Order_ID': 'CA-2015-124891', 'Sales': 2309.65}
# {'_id': ObjectId('685966dd8718115e852b367d'), 'Order_ID': 'CA-2015-124891', 'Sales': 1090.782}
# {'_id': ObjectId('685966dd8718115e852b3688'), 'Order_ID': 'US-2015-126214', 'Sales': 1618.37}
# {'_id': ObjectId('685966dd8718115e852b368e'), 'Order_ID': 'CA-2015-108665', 'Sales': 601.65}
# {'_id': ObjectId('685966dd8718115e852b3690'), 'Order_ID': 'CA-2015-124450', 'Sales': 1267.53}
# {'_id': ObjectId('685966dd8718115e852b3691'), 'Order_ID': 'CA-2015-124450', 'Sales': 1379.92}
# {'_id': ObjectId('685966dd8718115e852b3699'), 'Order_ID': 'CA-2014-163552', 'Sales': 854.94}
# {'_id': ObjectId('685966dd8718115e852b36a3'), 'Order_ID': 'CA-2016-127670', 'Sales': 697.16}
# {'_id': ObjectId('685966dd8718115e852b36a5'), 'Order_ID': 'CA-2016-102981', 'Sales': 722.352}
# {'_id': ObjectId('685966dd8718115e852b36a9'), 'Order_ID': 'CA-2016-169103', 'Sales': 1363.96}
# {'_id': ObjectId('685966dd8718115e852b36ab'), 'Order_ID': 'CA-2014-139192', 'Sales': 1113.504}
# {'_id': ObjectId('685966dd8718115e852b36cc'), 'Order_ID': 'CA-2015-110016', 'Sales': 1106.91}
# {'_id': ObjectId('685966dd8718115e852b36cd'), 'Order_ID': 'US-2016-143819', 'Sales': 836.592}
# {'_id': ObjectId('685966dd8718115e852b36d0'), 'Order_ID': 'US-2016-143819', 'Sales': 4899.93}
# {'_id': ObjectId('685966dd8718115e852b36f1'), 'Order_ID': 'CA-2015-142755', 'Sales': 619.95}
# {'_id': ObjectId('685966dd8718115e852b36f4'), 'Order_ID': 'US-2014-147627', 'Sales': 699.93}
# {'_id': ObjectId('685966dd8718115e852b36f9'), 'Order_ID': 'US-2014-147627', 'Sales': 1067.94}
# {'_id': ObjectId('685966dd8718115e852b370b'), 'Order_ID': 'CA-2014-146969', 'Sales': 686.32}
# {'_id': ObjectId('685966dd8718115e852b370d'), 'Order_ID': 'CA-2015-112452', 'Sales': 644.076}
# {'_id': ObjectId('685966dd8718115e852b3711'), 'Order_ID': 'CA-2015-112452', 'Sales': 599.98}
# {'_id': ObjectId('685966dd8718115e852b3716'), 'Order_ID': 'CA-2014-136567', 'Sales': 2244.48}
# {'_id': ObjectId('685966dd8718115e852b372f'), 'Order_ID': 'CA-2014-128146', 'Sales': 1322.93}
# {'_id': ObjectId('685966dd8718115e852b3738'), 'Order_ID': 'CA-2017-117212', 'Sales': 889.536}
# {'_id': ObjectId('685966dd8718115e852b3739'), 'Order_ID': 'CA-2017-117212', 'Sales': 892.224}
# {'_id': ObjectId('685966dd8718115e852b3742'), 'Order_ID': 'CA-2016-130946', 'Sales': 1088.792}
# {'_id': ObjectId('685966dd8718115e852b3743'), 'Order_ID': 'CA-2016-114727', 'Sales': 544.008}
# {'_id': ObjectId('685966dd8718115e852b3745'), 'Order_ID': 'CA-2016-114727', 'Sales': 854.352}
# {'_id': ObjectId('685966dd8718115e852b3746'), 'Order_ID': 'CA-2016-114727', 'Sales': 593.568}
# {'_id': ObjectId('685966dd8718115e852b374e'), 'Order_ID': 'CA-2016-137050', 'Sales': 579.136}
# {'_id': ObjectId('685966dd8718115e852b3756'), 'Order_ID': 'US-2017-118087', 'Sales': 1931.958}
# {'_id': ObjectId('685966dd8718115e852b3764'), 'Order_ID': 'CA-2016-153682', 'Sales': 839.988}
# {'_id': ObjectId('685966dd8718115e852b3770'), 'Order_ID': 'CA-2014-168494', 'Sales': 764.688}
# {'_id': ObjectId('685966dd8718115e852b3771'), 'Order_ID': 'CA-2014-168494', 'Sales': 3610.848}
# {'_id': ObjectId('685966dd8718115e852b3774'), 'Order_ID': 'CA-2017-115602', 'Sales': 1141.938}
# {'_id': ObjectId('685966dd8718115e852b3775'), 'Order_ID': 'CA-2017-115602', 'Sales': 1704.56}
# {'_id': ObjectId('685966dd8718115e852b3777'), 'Order_ID': 'CA-2015-154956', 'Sales': 1099.96}
# {'_id': ObjectId('685966dd8718115e852b377d'), 'Order_ID': 'US-2016-168620', 'Sales': 540.048}
# {'_id': ObjectId('685966dd8718115e852b377f'), 'Order_ID': 'CA-2017-117079', 'Sales': 863.88}
# {'_id': ObjectId('685966dd8718115e852b37a2'), 'Order_ID': 'CA-2015-138898', 'Sales': 845.728}
# {'_id': ObjectId('685966dd8718115e852b37a7'), 'Order_ID': 'CA-2016-137043', 'Sales': 572.76}
# {'_id': ObjectId('685966dd8718115e852b37b7'), 'Order_ID': 'CA-2016-145919', 'Sales': 579.3}
# {'_id': ObjectId('685966dd8718115e852b37b9'), 'Order_ID': 'CA-2014-160773', 'Sales': 575.92}
# {'_id': ObjectId('685966dd8718115e852b37ca'), 'Order_ID': 'CA-2016-122133', 'Sales': 552.56}
# {'_id': ObjectId('685966dd8718115e852b37cd'), 'Order_ID': 'CA-2017-100524', 'Sales': 677.58}
# {'_id': ObjectId('685966dd8718115e852b37cf'), 'Order_ID': 'CA-2017-113481', 'Sales': 695.7}
# {'_id': ObjectId('685966dd8718115e852b37ea'), 'Order_ID': 'US-2017-155425', 'Sales': 899.136}
# {'_id': ObjectId('685966dd8718115e852b37ec'), 'Order_ID': 'US-2015-103471', 'Sales': 590.058}
# {'_id': ObjectId('685966dd8718115e852b37f1'), 'Order_ID': 'CA-2015-120362', 'Sales': 912.75}
# {'_id': ObjectId('685966dd8718115e852b37f2'), 'Order_ID': 'CA-2014-126361', 'Sales': 1089.75}
# {'_id': ObjectId('685966dd8718115e852b3805'), 'Order_ID': 'US-2017-117247', 'Sales': 652.45}
# {'_id': ObjectId('685966dd8718115e852b381b'), 'Order_ID': 'CA-2015-126697', 'Sales': 946.344}
# {'_id': ObjectId('685966dd8718115e852b382c'), 'Order_ID': 'CA-2014-120768', 'Sales': 1819.86}
# {'_id': ObjectId('685966dd8718115e852b3831'), 'Order_ID': 'CA-2015-139731', 'Sales': 2453.43}
# {'_id': ObjectId('685966dd8718115e852b3837'), 'Order_ID': 'CA-2016-133725', 'Sales': 1979.928}
# {'_id': ObjectId('685966dd8718115e852b3841'), 'Order_ID': 'CA-2016-133711', 'Sales': 3040.0}
# {'_id': ObjectId('685966dd8718115e852b384a'), 'Order_ID': 'CA-2016-152289', 'Sales': 1024.716}
# {'_id': ObjectId('685966dd8718115e852b384f'), 'Order_ID': 'CA-2017-139199', 'Sales': 872.94}
# {'_id': ObjectId('685966dd8718115e852b3861'), 'Order_ID': 'CA-2015-140410', 'Sales': 1212.848}
# {'_id': ObjectId('685966dd8718115e852b3867'), 'Order_ID': 'CA-2017-166436', 'Sales': 977.292}
# {'_id': ObjectId('685966dd8718115e852b3870'), 'Order_ID': 'CA-2017-130386', 'Sales': 540.048}
# {'_id': ObjectId('685966dd8718115e852b3874'), 'Order_ID': 'CA-2015-153388', 'Sales': 1004.976}
# {'_id': ObjectId('685966dd8718115e852b387f'), 'Order_ID': 'CA-2017-148446', 'Sales': 1669.6}
# {'_id': ObjectId('685966dd8718115e852b3896'), 'Order_ID': 'CA-2017-121888', 'Sales': 782.94}
# {'_id': ObjectId('685966dd8718115e852b389c'), 'Order_ID': 'CA-2014-150245', 'Sales': 1573.488}
# {'_id': ObjectId('685966dd8718115e852b38a0'), 'Order_ID': 'CA-2014-134278', 'Sales': 559.992}
# {'_id': ObjectId('685966dd8718115e852b38ad'), 'Order_ID': 'US-2017-102890', 'Sales': 1044.63}
# {'_id': ObjectId('685966dd8718115e852b38b5'), 'Order_ID': 'US-2014-157385', 'Sales': 603.92}
# {'_id': ObjectId('685966dd8718115e852b38ba'), 'Order_ID': 'CA-2014-101602', 'Sales': 763.28}
# {'_id': ObjectId('685966dd8718115e852b38c1'), 'Order_ID': 'CA-2015-131338', 'Sales': 1217.568}
# {'_id': ObjectId('685966dd8718115e852b38c4'), 'Order_ID': 'CA-2015-131338', 'Sales': 979.95}
# {'_id': ObjectId('685966dd8718115e852b38cf'), 'Order_ID': 'CA-2017-132234', 'Sales': 547.3}
# {'_id': ObjectId('685966dd8718115e852b38e0'), 'Order_ID': 'CA-2017-138380', 'Sales': 1000.02}
# {'_id': ObjectId('685966dd8718115e852b38e8'), 'Order_ID': 'CA-2017-108560', 'Sales': 786.48}
# {'_id': ObjectId('685966dd8718115e852b38eb'), 'Order_ID': 'CA-2015-157084', 'Sales': 675.96}
# {'_id': ObjectId('685966dd8718115e852b38ec'), 'Order_ID': 'CA-2015-157084', 'Sales': 1265.85}
# {'_id': ObjectId('685966dd8718115e852b38ed'), 'Order_ID': 'CA-2015-164539', 'Sales': 523.25}
# {'_id': ObjectId('685966dd8718115e852b38ee'), 'Order_ID': 'CA-2015-143119', 'Sales': 517.5}
# {'_id': ObjectId('685966dd8718115e852b38f1'), 'Order_ID': 'CA-2016-106530', 'Sales': 1006.056}
# {'_id': ObjectId('685966dd8718115e852b38f7'), 'Order_ID': 'CA-2014-168984', 'Sales': 669.08}
# {'_id': ObjectId('685966dd8718115e852b38fe'), 'Order_ID': 'CA-2015-111829', 'Sales': 1247.64}
# {'_id': ObjectId('685966dd8718115e852b38ff'), 'Order_ID': 'CA-2015-111829', 'Sales': 3149.93}
# {'_id': ObjectId('685966dd8718115e852b3910'), 'Order_ID': 'CA-2017-144526', 'Sales': 677.58}
# {'_id': ObjectId('685966dd8718115e852b3918'), 'Order_ID': 'US-2015-157154', 'Sales': 1018.104}
# {'_id': ObjectId('685966dd8718115e852b392c'), 'Order_ID': 'CA-2014-142839', 'Sales': 853.092}
# {'_id': ObjectId('685966dd8718115e852b3936'), 'Order_ID': 'CA-2014-135657', 'Sales': 515.88}
# {'_id': ObjectId('685966dd8718115e852b3938'), 'Order_ID': 'CA-2015-114069', 'Sales': 1931.04}
# {'_id': ObjectId('685966dd8718115e852b3942'), 'Order_ID': 'CA-2017-123491', 'Sales': 1702.12}
# {'_id': ObjectId('685966dd8718115e852b3944'), 'Order_ID': 'US-2017-124968', 'Sales': 765.625}
# {'_id': ObjectId('685966dd8718115e852b3952'), 'Order_ID': 'US-2017-164056', 'Sales': 1048.35}
# {'_id': ObjectId('685966dd8718115e852b396b'), 'Order_ID': 'CA-2017-116715', 'Sales': 559.62}
# {'_id': ObjectId('685966dd8718115e852b396f'), 'Order_ID': 'CA-2015-135622', 'Sales': 1718.4}
# {'_id': ObjectId('685966dd8718115e852b398f'), 'Order_ID': 'CA-2015-154326', 'Sales': 699.98}
# {'_id': ObjectId('685966dd8718115e852b3992'), 'Order_ID': 'CA-2014-120474', 'Sales': 2807.84}
# {'_id': ObjectId('685966dd8718115e852b399e'), 'Order_ID': 'CA-2017-158379', 'Sales': 4663.736}
# {'_id': ObjectId('685966dd8718115e852b39a0'), 'Order_ID': 'US-2016-116729', 'Sales': 2575.944}
# {'_id': ObjectId('685966dd8718115e852b39a6'), 'Order_ID': 'CA-2014-132612', 'Sales': 1441.3}
# {'_id': ObjectId('685966dd8718115e852b39b6'), 'Order_ID': 'CA-2016-109344', 'Sales': 1127.976}
# {'_id': ObjectId('685966dd8718115e852b39b8'), 'Order_ID': 'CA-2014-103373', 'Sales': 779.796}
# {'_id': ObjectId('685966dd8718115e852b39b9'), 'Order_ID': 'CA-2017-145884', 'Sales': 1439.92}
# {'_id': ObjectId('685966dd8718115e852b39bc'), 'Order_ID': 'CA-2017-162691', 'Sales': 1439.982}
# {'_id': ObjectId('685966dd8718115e852b39bf'), 'Order_ID': 'CA-2017-122693', 'Sales': 1245.86}
# {'_id': ObjectId('685966dd8718115e852b39cd'), 'Order_ID': 'CA-2015-160472', 'Sales': 831.2}
# {'_id': ObjectId('685966dd8718115e852b39da'), 'Order_ID': 'US-2016-100839', 'Sales': 727.45}
# {'_id': ObjectId('685966dd8718115e852b39e2'), 'Order_ID': 'CA-2014-116932', 'Sales': 801.568}
# {'_id': ObjectId('685966dd8718115e852b39ed'), 'Order_ID': 'CA-2015-109512', 'Sales': 563.4}
# {'_id': ObjectId('685966dd8718115e852b39fb'), 'Order_ID': 'CA-2017-141789', 'Sales': 1793.98}
# {'_id': ObjectId('685966dd8718115e852b39fd'), 'Order_ID': 'CA-2014-169775', 'Sales': 505.176}
# {'_id': ObjectId('685966dd8718115e852b3a04'), 'Order_ID': 'CA-2017-154410', 'Sales': 909.12}
# {'_id': ObjectId('685966dd8718115e852b3a0b'), 'Order_ID': 'CA-2017-121503', 'Sales': 597.132}
# {'_id': ObjectId('685966dd8718115e852b3a12'), 'Order_ID': 'US-2017-111423', 'Sales': 895.92}
# {'_id': ObjectId('685966dd8718115e852b3a15'), 'Order_ID': 'CA-2016-156685', 'Sales': 863.64}
# {'_id': ObjectId('685966dd8718115e852b3a1d'), 'Order_ID': 'US-2017-101539', 'Sales': 659.976}
# {'_id': ObjectId('685966dd8718115e852b3a27'), 'Order_ID': 'CA-2016-112109', 'Sales': 662.88}
# {'_id': ObjectId('685966dd8718115e852b3a34'), 'Order_ID': 'CA-2017-157987', 'Sales': 1282.41}
# {'_id': ObjectId('685966dd8718115e852b3a4b'), 'Order_ID': 'CA-2014-110408', 'Sales': 1394.95}
# {'_id': ObjectId('685966dd8718115e852b3a4c'), 'Order_ID': 'CA-2014-110408', 'Sales': 545.88}
# {'_id': ObjectId('685966dd8718115e852b3a4e'), 'Order_ID': 'CA-2016-112669', 'Sales': 933.536}
# {'_id': ObjectId('685966dd8718115e852b3a55'), 'Order_ID': 'CA-2016-147417', 'Sales': 1439.976}
# {'_id': ObjectId('685966dd8718115e852b3a57'), 'Order_ID': 'CA-2015-127509', 'Sales': 1024.38}
# {'_id': ObjectId('685966dd8718115e852b3a72'), 'Order_ID': 'CA-2016-145905', 'Sales': 900.08}
# {'_id': ObjectId('685966dd8718115e852b3a77'), 'Order_ID': 'CA-2016-168354', 'Sales': 1606.23}
# {'_id': ObjectId('685966dd8718115e852b3a7a'), 'Order_ID': 'CA-2016-168354', 'Sales': 872.32}
# {'_id': ObjectId('685966dd8718115e852b3a91'), 'Order_ID': 'CA-2016-131835', 'Sales': 597.0}
# {'_id': ObjectId('685966dd8718115e852b3a9b'), 'Order_ID': 'CA-2017-120376', 'Sales': 1586.69}
# {'_id': ObjectId('685966dd8718115e852b3aa8'), 'Order_ID': 'CA-2015-133452', 'Sales': 710.832}
# {'_id': ObjectId('685966dd8718115e852b3aad'), 'Order_ID': 'CA-2017-122504', 'Sales': 761.544}
# {'_id': ObjectId('685966dd8718115e852b3ac2'), 'Order_ID': 'US-2016-146570', 'Sales': 511.84}
# {'_id': ObjectId('685966dd8718115e852b3ac7'), 'Order_ID': 'US-2014-140116', 'Sales': 636.408}
# {'_id': ObjectId('685966dd8718115e852b3ad4'), 'Order_ID': 'CA-2015-164882', 'Sales': 1295.84}
# {'_id': ObjectId('685966dd8718115e852b3ada'), 'Order_ID': 'CA-2017-155460', 'Sales': 895.92}
# {'_id': ObjectId('685966dd8718115e852b3af0'), 'Order_ID': 'CA-2014-159520', 'Sales': 991.764}
# {'_id': ObjectId('685966dd8718115e852b3aff'), 'Order_ID': 'CA-2014-124646', 'Sales': 501.81}
# {'_id': ObjectId('685966dd8718115e852b3b19'), 'Order_ID': 'CA-2016-128818', 'Sales': 3999.95}
# {'_id': ObjectId('685966dd8718115e852b3b20'), 'Order_ID': 'CA-2017-143063', 'Sales': 1454.49}
# {'_id': ObjectId('685966dd8718115e852b3b2c'), 'Order_ID': 'US-2014-165659', 'Sales': 881.93}
# {'_id': ObjectId('685966dd8718115e852b3b34'), 'Order_ID': 'CA-2014-125556', 'Sales': 832.93}
# {'_id': ObjectId('685966dd8718115e852b3b3f'), 'Order_ID': 'CA-2017-130841', 'Sales': 1145.6}
# {'_id': ObjectId('685966dd8718115e852b3b48'), 'Order_ID': 'CA-2014-128055', 'Sales': 673.568}
# {'_id': ObjectId('685966dd8718115e852b3b4a'), 'Order_ID': 'CA-2017-157091', 'Sales': 526.45}
# {'_id': ObjectId('685966dd8718115e852b3b52'), 'Order_ID': 'CA-2016-146633', 'Sales': 1016.792}
# {'_id': ObjectId('685966dd8718115e852b3b59'), 'Order_ID': 'CA-2017-103380', 'Sales': 659.976}
# {'_id': ObjectId('685966dd8718115e852b3b5d'), 'Order_ID': 'CA-2015-116092', 'Sales': 541.44}
# {'_id': ObjectId('685966dd8718115e852b3b64'), 'Order_ID': 'CA-2017-105214', 'Sales': 1212.96}
# {'_id': ObjectId('685966dd8718115e852b3b74'), 'Order_ID': 'CA-2015-142944', 'Sales': 1119.984}
# {'_id': ObjectId('685966dd8718115e852b3b7b'), 'Order_ID': 'CA-2017-142622', 'Sales': 614.272}
# {'_id': ObjectId('685966dd8718115e852b3b84'), 'Order_ID': 'CA-2017-115154', 'Sales': 892.98}
# {'_id': ObjectId('685966dd8718115e852b3b86'), 'Order_ID': 'CA-2015-149342', 'Sales': 595.38}
# {'_id': ObjectId('685966dd8718115e852b3b8d'), 'Order_ID': 'CA-2015-113145', 'Sales': 1399.93}
# {'_id': ObjectId('685966dd8718115e852b3b8e'), 'Order_ID': 'CA-2015-113145', 'Sales': 503.96}
# {'_id': ObjectId('685966dd8718115e852b3b92'), 'Order_ID': 'CA-2017-157931', 'Sales': 723.92}
# {'_id': ObjectId('685966dd8718115e852b3bac'), 'Order_ID': 'US-2015-147739', 'Sales': 547.136}
# {'_id': ObjectId('685966dd8718115e852b3bbe'), 'Order_ID': 'CA-2016-159373', 'Sales': 557.585}
# {'_id': ObjectId('685966dd8718115e852b3bc4'), 'Order_ID': 'CA-2015-111514', 'Sales': 1552.831}
# {'_id': ObjectId('685966dd8718115e852b3bc8'), 'Order_ID': 'US-2014-148838', 'Sales': 1579.746}
# {'_id': ObjectId('685966dd8718115e852b3bc9'), 'Order_ID': 'US-2014-148838', 'Sales': 1071.576}
# {'_id': ObjectId('685966dd8718115e852b3bca'), 'Order_ID': 'US-2014-148838', 'Sales': 613.908}
# {'_id': ObjectId('685966dd8718115e852b3bd3'), 'Order_ID': 'US-2016-129469', 'Sales': 532.704}
# {'_id': ObjectId('685966dd8718115e852b3bea'), 'Order_ID': 'US-2015-127040', 'Sales': 1619.91}
# {'_id': ObjectId('685966dd8718115e852b3bf2'), 'Order_ID': 'CA-2017-147361', 'Sales': 628.81}
# {'_id': ObjectId('685966dd8718115e852b3bf6'), 'Order_ID': 'US-2016-110170', 'Sales': 956.6648}
# {'_id': ObjectId('685966dd8718115e852b3bf7'), 'Order_ID': 'CA-2017-108574', 'Sales': 1115.91}
# {'_id': ObjectId('685966dd8718115e852b3c00'), 'Order_ID': 'CA-2014-151295', 'Sales': 629.064}
# {'_id': ObjectId('685966dd8718115e852b3c01'), 'Order_ID': 'CA-2016-156300', 'Sales': 754.45}
# {'_id': ObjectId('685966dd8718115e852b3c03'), 'Order_ID': 'CA-2017-168655', 'Sales': 595.0}
# {'_id': ObjectId('685966dd8718115e852b3c05'), 'Order_ID': 'CA-2016-107202', 'Sales': 2396.4}
# {'_id': ObjectId('685966dd8718115e852b3c16'), 'Order_ID': 'CA-2015-154746', 'Sales': 826.11}
# {'_id': ObjectId('685966dd8718115e852b3c17'), 'Order_ID': 'CA-2017-140053', 'Sales': 545.85}
# {'_id': ObjectId('685966dd8718115e852b3c1d'), 'Order_ID': 'CA-2016-146934', 'Sales': 662.84}
# {'_id': ObjectId('685966dd8718115e852b3c36'), 'Order_ID': 'CA-2017-128755', 'Sales': 571.44}
# {'_id': ObjectId('685966dd8718115e852b3c3f'), 'Order_ID': 'CA-2016-114972', 'Sales': 1101.48}
# {'_id': ObjectId('685966dd8718115e852b3c40'), 'Order_ID': 'CA-2017-102750', 'Sales': 1322.352}
# {'_id': ObjectId('685966dd8718115e852b3c44'), 'Order_ID': 'CA-2017-147956', 'Sales': 1003.62}
# {'_id': ObjectId('685966dd8718115e852b3c46'), 'Order_ID': 'CA-2017-126067', 'Sales': 1137.75}
# {'_id': ObjectId('685966dd8718115e852b3c4c'), 'Order_ID': 'CA-2015-141040', 'Sales': 631.96}
# {'_id': ObjectId('685966dd8718115e852b3c4f'), 'Order_ID': 'CA-2014-144624', 'Sales': 4548.81}
# {'_id': ObjectId('685966dd8718115e852b3c51'), 'Order_ID': 'CA-2016-146206', 'Sales': 719.96}
# {'_id': ObjectId('685966dd8718115e852b3c52'), 'Order_ID': 'CA-2014-136644', 'Sales': 647.84}
# {'_id': ObjectId('685966dd8718115e852b3c5c'), 'Order_ID': 'CA-2014-143917', 'Sales': 8187.65}
# {'_id': ObjectId('685966dd8718115e852b3c61'), 'Order_ID': 'CA-2016-136812', 'Sales': 1117.92}
# {'_id': ObjectId('685966dd8718115e852b3c67'), 'Order_ID': 'CA-2014-128888', 'Sales': 604.656}
# {'_id': ObjectId('685966dd8718115e852b3c6b'), 'Order_ID': 'CA-2016-124352', 'Sales': 868.59}
# {'_id': ObjectId('685966dd8718115e852b3c79'), 'Order_ID': 'US-2017-117723', 'Sales': 1801.632}
# {'_id': ObjectId('685966dd8718115e852b3c7e'), 'Order_ID': 'CA-2015-113404', 'Sales': 1348.704}
# {'_id': ObjectId('685966dd8718115e852b3c7f'), 'Order_ID': 'CA-2015-113404', 'Sales': 700.152}
# {'_id': ObjectId('685966dd8718115e852b3c87'), 'Order_ID': 'US-2015-128090', 'Sales': 1879.96}
# {'_id': ObjectId('685966dd8718115e852b3c8a'), 'Order_ID': 'CA-2017-101042', 'Sales': 821.88}
# {'_id': ObjectId('685966dd8718115e852b3c8d'), 'Order_ID': 'CA-2016-118626', 'Sales': 705.544}
# {'_id': ObjectId('685966dd8718115e852b3c91'), 'Order_ID': 'CA-2015-147788', 'Sales': 1406.86}
# {'_id': ObjectId('685966dd8718115e852b3c9a'), 'Order_ID': 'CA-2017-123967', 'Sales': 2665.62}
# {'_id': ObjectId('685966dd8718115e852b3c9f'), 'Order_ID': 'CA-2016-155845', 'Sales': 1399.944}
# {'_id': ObjectId('685966dd8718115e852b3ca0'), 'Order_ID': 'CA-2017-145128', 'Sales': 526.45}
# {'_id': ObjectId('685966dd8718115e852b3ca4'), 'Order_ID': 'CA-2014-129091', 'Sales': 675.12}
# {'_id': ObjectId('685966dd8718115e852b3cb2'), 'Order_ID': 'US-2016-115455', 'Sales': 601.47}
# {'_id': ObjectId('685966dd8718115e852b3cb6'), 'Order_ID': 'CA-2017-149048', 'Sales': 914.97}
# {'_id': ObjectId('685966dd8718115e852b3cb7'), 'Order_ID': 'CA-2017-149048', 'Sales': 587.97}
# {'_id': ObjectId('685966dd8718115e852b3cb8'), 'Order_ID': 'CA-2017-149048', 'Sales': 530.34}
# {'_id': ObjectId('685966dd8718115e852b3cbd'), 'Order_ID': 'CA-2016-165848', 'Sales': 1349.85}
# {'_id': ObjectId('685966dd8718115e852b3cc4'), 'Order_ID': 'CA-2014-127446', 'Sales': 1218.735}
# {'_id': ObjectId('685966dd8718115e852b3cd2'), 'Order_ID': 'CA-2017-127180', 'Sales': 11199.968}
# {'_id': ObjectId('685966dd8718115e852b3cd3'), 'Order_ID': 'CA-2017-127180', 'Sales': 2399.6}
# {'_id': ObjectId('685966dd8718115e852b3cd7'), 'Order_ID': 'US-2017-165344', 'Sales': 652.995}
# {'_id': ObjectId('685966dd8718115e852b3ce3'), 'Order_ID': 'CA-2017-108441', 'Sales': 858.24}
# {'_id': ObjectId('685966dd8718115e852b3ceb'), 'Order_ID': 'CA-2014-131002', 'Sales': 821.88}
# {'_id': ObjectId('685966dd8718115e852b3cf1'), 'Order_ID': 'CA-2017-112515', 'Sales': 1292.94}
# {'_id': ObjectId('685966dd8718115e852b3cf6'), 'Order_ID': 'CA-2015-135538', 'Sales': 883.84}
# {'_id': ObjectId('685966dd8718115e852b3cf7'), 'Order_ID': 'CA-2017-123372', 'Sales': 1979.89}
# {'_id': ObjectId('685966dd8718115e852b3d02'), 'Order_ID': 'CA-2014-126403', 'Sales': 785.88}
# {'_id': ObjectId('685966dd8718115e852b3d04'), 'Order_ID': 'CA-2014-126403', 'Sales': 1325.85}
# {'_id': ObjectId('685966dd8718115e852b3d0b'), 'Order_ID': 'CA-2017-127026', 'Sales': 619.95}
# {'_id': ObjectId('685966dd8718115e852b3d1b'), 'Order_ID': 'CA-2014-145317', 'Sales': 821.3}
# {'_id': ObjectId('685966dd8718115e852b3d1c'), 'Order_ID': 'CA-2014-145317', 'Sales': 22638.48}
# {'_id': ObjectId('685966dd8718115e852b3d28'), 'Order_ID': 'CA-2015-121797', 'Sales': 1919.976}
# {'_id': ObjectId('685966dd8718115e852b3d3b'), 'Order_ID': 'CA-2017-119193', 'Sales': 629.958}
# {'_id': ObjectId('685966dd8718115e852b3d3d'), 'Order_ID': 'CA-2017-104801', 'Sales': 799.96}
# {'_id': ObjectId('685966dd8718115e852b3d4d'), 'Order_ID': 'CA-2014-155887', 'Sales': 700.056}
# {'_id': ObjectId('685966dd8718115e852b3d50'), 'Order_ID': 'US-2014-141257', 'Sales': 585.552}
# {'_id': ObjectId('685966dd8718115e852b3d55'), 'Order_ID': 'CA-2015-155306', 'Sales': 783.96}
# {'_id': ObjectId('685966dd8718115e852b3d56'), 'Order_ID': 'CA-2015-155306', 'Sales': 1447.65}
# {'_id': ObjectId('685966dd8718115e852b3d62'), 'Order_ID': 'CA-2017-167752', 'Sales': 1924.16}
# {'_id': ObjectId('685966dd8718115e852b3d74'), 'Order_ID': 'CA-2015-149972', 'Sales': 601.536}
# {'_id': ObjectId('685966dd8718115e852b3d7c'), 'Order_ID': 'CA-2014-154599', 'Sales': 1075.088}
# {'_id': ObjectId('685966dd8718115e852b3d83'), 'Order_ID': 'CA-2016-153318', 'Sales': 783.96}
# {'_id': ObjectId('685966dd8718115e852b3d8b'), 'Order_ID': 'CA-2015-148635', 'Sales': 704.9}
# {'_id': ObjectId('685966dd8718115e852b3d8c'), 'Order_ID': 'CA-2015-148635', 'Sales': 561.568}
# {'_id': ObjectId('685966dd8718115e852b3d90'), 'Order_ID': 'CA-2015-135685', 'Sales': 999.96}
# {'_id': ObjectId('685966dd8718115e852b3d91'), 'Order_ID': 'CA-2015-135685', 'Sales': 653.55}
# {'_id': ObjectId('685966dd8718115e852b3d95'), 'Order_ID': 'CA-2015-104626', 'Sales': 1088.76}
# {'_id': ObjectId('685966dd8718115e852b3da9'), 'Order_ID': 'CA-2016-147368', 'Sales': 695.7}
# {'_id': ObjectId('685966dd8718115e852b3dab'), 'Order_ID': 'US-2014-125521', 'Sales': 1139.92}
# {'_id': ObjectId('685966dd8718115e852b3daf'), 'Order_ID': 'US-2016-162852', 'Sales': 845.488}
# {'_id': ObjectId('685966dd8718115e852b3db1'), 'Order_ID': 'CA-2017-152093', 'Sales': 762.594}
# {'_id': ObjectId('685966dd8718115e852b3db3'), 'Order_ID': 'CA-2017-157854', 'Sales': 2690.97}
# {'_id': ObjectId('685966dd8718115e852b3dbb'), 'Order_ID': 'CA-2016-128594', 'Sales': 1603.136}
# {'_id': ObjectId('685966dd8718115e852b3dbf'), 'Order_ID': 'CA-2017-138975', 'Sales': 1628.82}
# {'_id': ObjectId('685966dd8718115e852b3dcc'), 'Order_ID': 'CA-2017-137022', 'Sales': 811.28}
# {'_id': ObjectId('685966dd8718115e852b3dcf'), 'Order_ID': 'US-2016-167339', 'Sales': 1013.488}
# {'_id': ObjectId('685966dd8718115e852b3de4'), 'Order_ID': 'US-2016-164630', 'Sales': 959.968}
# {'_id': ObjectId('685966dd8718115e852b3deb'), 'Order_ID': 'CA-2016-153577', 'Sales': 539.658}
# {'_id': ObjectId('685966dd8718115e852b3e03'), 'Order_ID': 'US-2017-120390', 'Sales': 1633.188}
# {'_id': ObjectId('685966dd8718115e852b3e10'), 'Order_ID': 'CA-2017-155880', 'Sales': 1526.56}
# {'_id': ObjectId('685966dd8718115e852b3e1d'), 'Order_ID': 'CA-2017-134915', 'Sales': 671.984}
# {'_id': ObjectId('685966dd8718115e852b3e35'), 'Order_ID': 'CA-2014-109232', 'Sales': 545.94}
# {'_id': ObjectId('685966dd8718115e852b3e3e'), 'Order_ID': 'CA-2016-139269', 'Sales': 1267.65}
# {'_id': ObjectId('685966dd8718115e852b3e44'), 'Order_ID': 'CA-2017-147291', 'Sales': 895.92}
# {'_id': ObjectId('685966dd8718115e852b3e51'), 'Order_ID': 'CA-2017-116519', 'Sales': 904.9}
# {'_id': ObjectId('685966dd8718115e852b3e56'), 'Order_ID': 'CA-2017-134845', 'Sales': 2549.985}
# {'_id': ObjectId('685966dd8718115e852b3e5b'), 'Order_ID': 'US-2016-160528', 'Sales': 727.296}
# {'_id': ObjectId('685966dd8718115e852b3e5d'), 'Order_ID': 'US-2016-160528', 'Sales': 666.4}
# {'_id': ObjectId('685966dd8718115e852b3e67'), 'Order_ID': 'CA-2017-116855', 'Sales': 504.9}
# {'_id': ObjectId('685966dd8718115e852b3e76'), 'Order_ID': 'CA-2017-149559', 'Sales': 2054.272}
# {'_id': ObjectId('685966dd8718115e852b3e77'), 'Order_ID': 'CA-2015-135174', 'Sales': 1022.97}
# {'_id': ObjectId('685966dd8718115e852b3e80'), 'Order_ID': 'CA-2016-128517', 'Sales': 517.9}
# {'_id': ObjectId('685966dd8718115e852b3e82'), 'Order_ID': 'US-2015-100377', 'Sales': 2799.96}
# {'_id': ObjectId('685966dd8718115e852b3e90'), 'Order_ID': 'US-2017-120089', 'Sales': 663.936}
# {'_id': ObjectId('685966dd8718115e852b3e91'), 'Order_ID': 'CA-2014-119375', 'Sales': 2934.33}
# {'_id': ObjectId('685966dd8718115e852b3e98'), 'Order_ID': 'CA-2014-143903', 'Sales': 981.372}
# {'_id': ObjectId('685966dd8718115e852b3e9d'), 'Order_ID': 'US-2017-132297', 'Sales': 539.97}
# {'_id': ObjectId('685966dd8718115e852b3ea4'), 'Order_ID': 'US-2017-159205', 'Sales': 671.93}
# {'_id': ObjectId('685966dd8718115e852b3eb0'), 'Order_ID': 'CA-2017-119578', 'Sales': 695.16}
# {'_id': ObjectId('685966dd8718115e852b3ebb'), 'Order_ID': 'CA-2016-150350', 'Sales': 837.6}
# {'_id': ObjectId('685966dd8718115e852b3ebe'), 'Order_ID': 'CA-2016-150350', 'Sales': 532.704}
# {'_id': ObjectId('685966dd8718115e852b3ec1'), 'Order_ID': 'CA-2015-121720', 'Sales': 1123.92}
# {'_id': ObjectId('685966dd8718115e852b3ec7'), 'Order_ID': 'CA-2015-121720', 'Sales': 1036.624}
# {'_id': ObjectId('685966dd8718115e852b3ec8'), 'Order_ID': 'CA-2015-121720', 'Sales': 563.808}
# {'_id': ObjectId('685966dd8718115e852b3ece'), 'Order_ID': 'CA-2014-136399', 'Sales': 627.168}
# {'_id': ObjectId('685966dd8718115e852b3edc'), 'Order_ID': 'CA-2017-131828', 'Sales': 963.136}
# {'_id': ObjectId('685966dd8718115e852b3ee1'), 'Order_ID': 'CA-2015-147830', 'Sales': 2025.36}
# {'_id': ObjectId('685966dd8718115e852b3ee2'), 'Order_ID': 'CA-2015-147830', 'Sales': 1799.994}
# {'_id': ObjectId('685966dd8718115e852b3ee5'), 'Order_ID': 'CA-2017-150497', 'Sales': 735.98}
# {'_id': ObjectId('685966dd8718115e852b3ef7'), 'Order_ID': 'US-2016-133879', 'Sales': 528.43}
# {'_id': ObjectId('685966dd8718115e852b3f01'), 'Order_ID': 'CA-2017-152912', 'Sales': 826.62}
# {'_id': ObjectId('685966dd8718115e852b3f02'), 'Order_ID': 'CA-2017-152912', 'Sales': 1633.14}
# {'_id': ObjectId('685966dd8718115e852b3f03'), 'Order_ID': 'CA-2017-152912', 'Sales': 544.38}
# {'_id': ObjectId('685966dd8718115e852b3f15'), 'Order_ID': 'CA-2014-158372', 'Sales': 601.536}
# {'_id': ObjectId('685966dd8718115e852b3f24'), 'Order_ID': 'CA-2017-104640', 'Sales': 931.176}
# {'_id': ObjectId('685966dd8718115e852b3f51'), 'Order_ID': 'CA-2014-140662', 'Sales': 733.95}
# {'_id': ObjectId('685966dd8718115e852b3f5c'), 'Order_ID': 'CA-2017-133865', 'Sales': 3359.952}
# {'_id': ObjectId('685966dd8718115e852b3f63'), 'Order_ID': 'CA-2014-102988', 'Sales': 4164.05}
# {'_id': ObjectId('685966dd8718115e852b3f72'), 'Order_ID': 'CA-2017-113418', 'Sales': 1704.89}
# {'_id': ObjectId('685966dd8718115e852b3f75'), 'Order_ID': 'CA-2017-136308', 'Sales': 1919.976}
# {'_id': ObjectId('685966dd8718115e852b3f78'), 'Order_ID': 'US-2014-159926', 'Sales': 539.964}
# {'_id': ObjectId('685966dd8718115e852b3f83'), 'Order_ID': 'US-2014-133130', 'Sales': 603.92}
# {'_id': ObjectId('685966dd8718115e852b3f8b'), 'Order_ID': 'CA-2014-134551', 'Sales': 662.88}
# {'_id': ObjectId('685966dd8718115e852b3f8f'), 'Order_ID': 'CA-2014-165309', 'Sales': 896.99}
# {'_id': ObjectId('685966dd8718115e852b3f9c'), 'Order_ID': 'US-2017-109253', 'Sales': 568.728}
# {'_id': ObjectId('685966dd8718115e852b3fbd'), 'Order_ID': 'CA-2016-134887', 'Sales': 1287.45}
# {'_id': ObjectId('685966dd8718115e852b3fcb'), 'Order_ID': 'CA-2015-130659', 'Sales': 1799.75}
# {'_id': ObjectId('685966dd8718115e852b3fcc'), 'Order_ID': 'CA-2017-148404', 'Sales': 580.672}
# {'_id': ObjectId('685966dd8718115e852b3fd2'), 'Order_ID': 'CA-2014-166471', 'Sales': 1091.168}
# {'_id': ObjectId('685966dd8718115e852b3fda'), 'Order_ID': 'CA-2014-102274', 'Sales': 629.1}
# {'_id': ObjectId('685966dd8718115e852b3ff3'), 'Order_ID': 'CA-2016-134803', 'Sales': 558.4}
# {'_id': ObjectId('685966dd8718115e852b3ff5'), 'Order_ID': 'CA-2015-153381', 'Sales': 1408.1}
# {'_id': ObjectId('685966dd8718115e852b4006'), 'Order_ID': 'CA-2017-168858', 'Sales': 2504.74}
# {'_id': ObjectId('685966dd8718115e852b4016'), 'Order_ID': 'CA-2017-136448', 'Sales': 538.194}
# {'_id': ObjectId('685966dd8718115e852b402b'), 'Order_ID': 'CA-2016-131289', 'Sales': 1421.664}
# {'_id': ObjectId('685966dd8718115e852b402d'), 'Order_ID': 'CA-2014-124688', 'Sales': 579.95}
# {'_id': ObjectId('685966dd8718115e852b402f'), 'Order_ID': 'CA-2014-124688', 'Sales': 1202.94}
# {'_id': ObjectId('685966dd8718115e852b4039'), 'Order_ID': 'CA-2017-142034', 'Sales': 655.9}
# {'_id': ObjectId('685966dd8718115e852b403a'), 'Order_ID': 'CA-2017-142034', 'Sales': 603.92}
# {'_id': ObjectId('685966dd8718115e852b403b'), 'Order_ID': 'CA-2016-107328', 'Sales': 513.024}
# {'_id': ObjectId('685966dd8718115e852b4043'), 'Order_ID': 'CA-2016-150945', 'Sales': 900.08}
# {'_id': ObjectId('685966dd8718115e852b404a'), 'Order_ID': 'CA-2014-166863', 'Sales': 509.488}
# {'_id': ObjectId('685966dd8718115e852b404b'), 'Order_ID': 'CA-2017-140326', 'Sales': 825.174}
# {'_id': ObjectId('685966dd8718115e852b4051'), 'Order_ID': 'US-2016-113649', 'Sales': 569.536}
# {'_id': ObjectId('685966dd8718115e852b4052'), 'Order_ID': 'CA-2015-124975', 'Sales': 796.425}
# {'_id': ObjectId('685966dd8718115e852b4057'), 'Order_ID': 'CA-2016-132731', 'Sales': 657.552}
# {'_id': ObjectId('685966dd8718115e852b4058'), 'Order_ID': 'CA-2017-148922', 'Sales': 599.97}
# {'_id': ObjectId('685966dd8718115e852b4072'), 'Order_ID': 'CA-2016-152555', 'Sales': 844.116}
# {'_id': ObjectId('685966dd8718115e852b4073'), 'Order_ID': 'CA-2016-152555', 'Sales': 812.736}
# {'_id': ObjectId('685966dd8718115e852b4076'), 'Order_ID': 'CA-2014-120838', 'Sales': 604.752}
# {'_id': ObjectId('685966dd8718115e852b4081'), 'Order_ID': 'CA-2017-103877', 'Sales': 1577.94}
# {'_id': ObjectId('685966dd8718115e852b4084'), 'Order_ID': 'CA-2017-168109', 'Sales': 2395.2}
# {'_id': ObjectId('685966dd8718115e852b4085'), 'Order_ID': 'CA-2017-168109', 'Sales': 1687.8}
# {'_id': ObjectId('685966dd8718115e852b408f'), 'Order_ID': 'CA-2016-104157', 'Sales': 2430.08}
# {'_id': ObjectId('685966dd8718115e852b4092'), 'Order_ID': 'CA-2015-121650', 'Sales': 801.96}
# {'_id': ObjectId('685966dd8718115e852b4096'), 'Order_ID': 'CA-2017-121839', 'Sales': 1169.694}
# {'_id': ObjectId('685966dd8718115e852b4097'), 'Order_ID': 'CA-2017-158729', 'Sales': 1665.62}
# {'_id': ObjectId('685966dd8718115e852b4099'), 'Order_ID': 'CA-2017-146535', 'Sales': 1443.96}
# {'_id': ObjectId('685966dd8718115e852b40a5'), 'Order_ID': 'CA-2014-159835', 'Sales': 657.93}
# {'_id': ObjectId('685966dd8718115e852b40b1'), 'Order_ID': 'CA-2017-112529', 'Sales': 718.116}
# {'_id': ObjectId('685966dd8718115e852b40bb'), 'Order_ID': 'CA-2017-113530', 'Sales': 681.408}
# {'_id': ObjectId('685966dd8718115e852b40bf'), 'Order_ID': 'CA-2014-169726', 'Sales': 2060.744}
# {'_id': ObjectId('685966dd8718115e852b40c3'), 'Order_ID': 'CA-2017-132178', 'Sales': 763.44}
# {'_id': ObjectId('685966dd8718115e852b40d9'), 'Order_ID': 'CA-2017-133004', 'Sales': 638.73}
# {'_id': ObjectId('685966dd8718115e852b410b'), 'Order_ID': 'CA-2015-104941', 'Sales': 899.97}
# {'_id': ObjectId('685966dd8718115e852b4111'), 'Order_ID': 'CA-2017-113670', 'Sales': 510.24}
# {'_id': ObjectId('685966dd8718115e852b4116'), 'Order_ID': 'CA-2014-135608', 'Sales': 603.92}
# {'_id': ObjectId('685966dd8718115e852b411e'), 'Order_ID': 'US-2014-169789', 'Sales': 551.985}
# {'_id': ObjectId('685966dd8718115e852b4125'), 'Order_ID': 'CA-2015-109575', 'Sales': 636.86}
# {'_id': ObjectId('685966dd8718115e852b4127'), 'Order_ID': 'CA-2015-109575', 'Sales': 1259.93}
# {'_id': ObjectId('685966dd8718115e852b4138'), 'Order_ID': 'CA-2017-161956', 'Sales': 879.984}
# {'_id': ObjectId('685966dd8718115e852b413c'), 'Order_ID': 'CA-2017-161956', 'Sales': 841.568}
# {'_id': ObjectId('685966dd8718115e852b413f'), 'Order_ID': 'CA-2016-116799', 'Sales': 563.43}
# {'_id': ObjectId('685966dd8718115e852b414b'), 'Order_ID': 'CA-2014-153913', 'Sales': 1013.832}
# {'_id': ObjectId('685966dd8718115e852b414d'), 'Order_ID': 'CA-2016-155530', 'Sales': 2003.52}
# {'_id': ObjectId('685966dd8718115e852b4154'), 'Order_ID': 'CA-2015-107937', 'Sales': 665.88}
# {'_id': ObjectId('685966dd8718115e852b415a'), 'Order_ID': 'CA-2017-165204', 'Sales': 720.064}
# {'_id': ObjectId('685966dd8718115e852b415d'), 'Order_ID': 'CA-2016-144218', 'Sales': 1085.42}
# {'_id': ObjectId('685966dd8718115e852b4169'), 'Order_ID': 'CA-2017-147760', 'Sales': 523.764}
# {'_id': ObjectId('685966dd8718115e852b416a'), 'Order_ID': 'CA-2017-147760', 'Sales': 1359.96}
# {'_id': ObjectId('685966dd8718115e852b4174'), 'Order_ID': 'CA-2015-113628', 'Sales': 523.92}
# {'_id': ObjectId('685966dd8718115e852b4179'), 'Order_ID': 'CA-2016-152471', 'Sales': 823.96}
# {'_id': ObjectId('685966dd8718115e852b417b'), 'Order_ID': 'CA-2015-102582', 'Sales': 801.96}
# {'_id': ObjectId('685966dd8718115e852b417d'), 'Order_ID': 'CA-2015-102582', 'Sales': 1056.86}
# {'_id': ObjectId('685966dd8718115e852b4182'), 'Order_ID': 'CA-2015-140984', 'Sales': 991.2}
# {'_id': ObjectId('685966dd8718115e852b4183'), 'Order_ID': 'CA-2015-140984', 'Sales': 879.984}
# {'_id': ObjectId('685966dd8718115e852b4186'), 'Order_ID': 'CA-2017-141733', 'Sales': 1458.65}
# {'_id': ObjectId('685966dd8718115e852b418c'), 'Order_ID': 'CA-2014-105984', 'Sales': 1049.97}
# {'_id': ObjectId('685966dd8718115e852b418d'), 'Order_ID': 'CA-2014-105984', 'Sales': 611.058}
# {'_id': ObjectId('685966dd8718115e852b4190'), 'Order_ID': 'CA-2014-126760', 'Sales': 911.984}
# {'_id': ObjectId('685966dd8718115e852b4191'), 'Order_ID': 'CA-2014-126760', 'Sales': 674.352}
# {'_id': ObjectId('685966dd8718115e852b4198'), 'Order_ID': 'CA-2014-101931', 'Sales': 616.998}
# {'_id': ObjectId('685966dd8718115e852b419a'), 'Order_ID': 'CA-2017-129000', 'Sales': 501.81}
# {'_id': ObjectId('685966dd8718115e852b419b'), 'Order_ID': 'CA-2017-161053', 'Sales': 691.96}
# {'_id': ObjectId('685966dd8718115e852b41a3'), 'Order_ID': 'US-2017-105389', 'Sales': 823.96}
# {'_id': ObjectId('685966dd8718115e852b41b3'), 'Order_ID': 'CA-2015-132486', 'Sales': 842.352}
# {'_id': ObjectId('685966dd8718115e852b41c5'), 'Order_ID': 'US-2016-163881', 'Sales': 659.9}
# {'_id': ObjectId('685966dd8718115e852b41c6'), 'Order_ID': 'US-2016-163881', 'Sales': 1684.752}
# {'_id': ObjectId('685966dd8718115e852b41c7'), 'Order_ID': 'US-2016-163881', 'Sales': 559.92}
# {'_id': ObjectId('685966dd8718115e852b41d3'), 'Order_ID': 'CA-2015-167010', 'Sales': 563.808}
# {'_id': ObjectId('685966dd8718115e852b41d5'), 'Order_ID': 'CA-2015-167010', 'Sales': 547.136}
# {'_id': ObjectId('685966dd8718115e852b41dd'), 'Order_ID': 'US-2017-142573', 'Sales': 801.6}
# {'_id': ObjectId('685966dd8718115e852b41f6'), 'Order_ID': 'US-2016-143448', 'Sales': 1424.9}
# {'_id': ObjectId('685966dd8718115e852b41fa'), 'Order_ID': 'US-2016-142685', 'Sales': 835.17}
# {'_id': ObjectId('685966dd8718115e852b4222'), 'Order_ID': 'CA-2016-135265', 'Sales': 2799.96}
# {'_id': ObjectId('685966dd8718115e852b4225'), 'Order_ID': 'CA-2017-112333', 'Sales': 2591.56}
# {'_id': ObjectId('685966dd8718115e852b422d'), 'Order_ID': 'CA-2015-105627', 'Sales': 512.94}
# {'_id': ObjectId('685966dd8718115e852b422e'), 'Order_ID': 'CA-2015-105627', 'Sales': 860.93}
# {'_id': ObjectId('685966dd8718115e852b422f'), 'Order_ID': 'CA-2015-105627', 'Sales': 769.95}
# {'_id': ObjectId('685966dd8718115e852b4235'), 'Order_ID': 'CA-2016-145730', 'Sales': 637.896}
# {'_id': ObjectId('685966dd8718115e852b4240'), 'Order_ID': 'CA-2015-165624', 'Sales': 542.94}
# {'_id': ObjectId('685966dd8718115e852b4249'), 'Order_ID': 'CA-2014-154963', 'Sales': 853.93}
# {'_id': ObjectId('685966dd8718115e852b424a'), 'Order_ID': 'CA-2017-130764', 'Sales': 556.665}
# {'_id': ObjectId('685966dd8718115e852b425a'), 'Order_ID': 'CA-2014-110786', 'Sales': 767.952}
# {'_id': ObjectId('685966dd8718115e852b4263'), 'Order_ID': 'US-2015-166520', 'Sales': 599.9}
# {'_id': ObjectId('685966dd8718115e852b426a'), 'Order_ID': 'CA-2014-122931', 'Sales': 1801.632}
# {'_id': ObjectId('685966dd8718115e852b426c'), 'Order_ID': 'CA-2014-163034', 'Sales': 646.2}
# {'_id': ObjectId('685966dd8718115e852b426e'), 'Order_ID': 'CA-2015-124058', 'Sales': 572.16}
# {'_id': ObjectId('685966dd8718115e852b4277'), 'Order_ID': 'CA-2014-102673', 'Sales': 978.84}
# {'_id': ObjectId('685966dd8718115e852b427b'), 'Order_ID': 'CA-2015-156104', 'Sales': 999.98}
# {'_id': ObjectId('685966dd8718115e852b427c'), 'Order_ID': 'US-2015-164308', 'Sales': 821.94}
# {'_id': ObjectId('685966dd8718115e852b428b'), 'Order_ID': 'US-2014-156559', 'Sales': 638.82}
# {'_id': ObjectId('685966dd8718115e852b4290'), 'Order_ID': 'CA-2015-102491', 'Sales': 3080.0}
# {'_id': ObjectId('685966dd8718115e852b4292'), 'Order_ID': 'CA-2015-102491', 'Sales': 587.97}
# {'_id': ObjectId('685966dd8718115e852b4295'), 'Order_ID': 'CA-2014-116904', 'Sales': 9449.95}
# {'_id': ObjectId('685966dd8718115e852b42a6'), 'Order_ID': 'CA-2016-163573', 'Sales': 1219.96}
# {'_id': ObjectId('685966dd8718115e852b42b3'), 'Order_ID': 'CA-2014-127299', 'Sales': 2624.985}
# {'_id': ObjectId('685966dd8718115e852b42bb'), 'Order_ID': 'CA-2017-105914', 'Sales': 1575.14}
# {'_id': ObjectId('685966dd8718115e852b42d3'), 'Order_ID': 'CA-2017-115546', 'Sales': 539.97}
# {'_id': ObjectId('685966dd8718115e852b42d6'), 'Order_ID': 'CA-2015-163587', 'Sales': 671.94}
# ...
# {'_id': ObjectId('685966dd8718115e852b5300'), 'Order_ID': 'US-2017-167318', 'Sales': 1649.95}
# {'_id': ObjectId('685966dd8718115e852b530b'), 'Order_ID': 'US-2017-105935', 'Sales': 2939.93}
# {'_id': ObjectId('685966dd8718115e852b530c'), 'Order_ID': 'CA-2014-161508', 'Sales': 512.358}
# {'_id': ObjectId('685966dd8718115e852b533d'), 'Order_ID': 'CA-2017-147207', 'Sales': 913.43}
# {'_id': ObjectId('685966dd8718115e852b533f'), 'Order_ID': 'CA-2017-137631', 'Sales': 751.984}
# {'_id': ObjectId('685966dd8718115e852b5340'), 'Order_ID': 'CA-2017-157273', 'Sales': 604.768}
# {'_id': ObjectId('685966dd8718115e852b5344'), 'Order_ID': 'CA-2016-118745', 'Sales': 902.712}
# {'_id': ObjectId('685966dd8718115e852b535d'), 'Order_ID': 'CA-2016-142594', 'Sales': 901.95}
# {'_id': ObjectId('685966dd8718115e852b536d'), 'Order_ID': 'CA-2016-130820', 'Sales': 630.024}
# {'_id': ObjectId('685966dd8718115e852b536f'), 'Order_ID': 'CA-2017-132290', 'Sales': 933.408}
# {'_id': ObjectId('685966dd8718115e852b537b'), 'Order_ID': 'CA-2017-150091', 'Sales': 2154.9}
# {'_id': ObjectId('685966dd8718115e852b5393'), 'Order_ID': 'CA-2017-125451', 'Sales': 637.896}
# {'_id': ObjectId('685966dd8718115e852b5396'), 'Order_ID': 'CA-2014-131387', 'Sales': 1679.96}
# {'_id': ObjectId('685966dd8718115e852b5398'), 'Order_ID': 'CA-2016-125087', 'Sales': 1554.936}
# {'_id': ObjectId('685966dd8718115e852b53a7'), 'Order_ID': 'US-2016-164196', 'Sales': 2678.94}
# {'_id': ObjectId('685966dd8718115e852b53b0'), 'Order_ID': 'CA-2015-145758', 'Sales': 1035.8}
# {'_id': ObjectId('685966dd8718115e852b53bb'), 'Order_ID': 'CA-2016-158841', 'Sales': 8749.95}
# {'_id': ObjectId('685966dd8718115e852b53fb'), 'Order_ID': 'CA-2014-140473', 'Sales': 719.976}
# {'_id': ObjectId('685966dd8718115e852b53fd'), 'Order_ID': 'CA-2016-102092', 'Sales': 1056.86}
# {'_id': ObjectId('685966dd8718115e852b5405'), 'Order_ID': 'CA-2016-123540', 'Sales': 1454.9}
# {'_id': ObjectId('685966dd8718115e852b540b'), 'Order_ID': 'CA-2016-162390', 'Sales': 968.744}
# {'_id': ObjectId('685966dd8718115e852b540f'), 'Order_ID': 'CA-2014-121629', 'Sales': 998.85}
# {'_id': ObjectId('685966dd8718115e852b5414'), 'Order_ID': 'CA-2017-146164', 'Sales': 607.52}
# {'_id': ObjectId('685966dd8718115e852b541d'), 'Order_ID': 'CA-2017-162015', 'Sales': 1287.45}
# {'_id': ObjectId('685966dd8718115e852b544b'), 'Order_ID': 'CA-2016-107783', 'Sales': 1369.764}
# {'_id': ObjectId('685966dd8718115e852b544f'), 'Order_ID': 'CA-2014-160094', 'Sales': 826.0}
# {'_id': ObjectId('685966dd8718115e852b5453'), 'Order_ID': 'US-2017-148551', 'Sales': 760.98}
# {'_id': ObjectId('685966dd8718115e852b545b'), 'Order_ID': 'CA-2016-164574', 'Sales': 704.76}
# {'_id': ObjectId('685966dd8718115e852b5467'), 'Order_ID': 'CA-2017-124765', 'Sales': 723.92}
# {'_id': ObjectId('685966dd8718115e852b5469'), 'Order_ID': 'CA-2015-131856', 'Sales': 619.152}
# {'_id': ObjectId('685966dd8718115e852b5474'), 'Order_ID': 'CA-2017-163265', 'Sales': 600.558}
# {'_id': ObjectId('685966dd8718115e852b5478'), 'Order_ID': 'CA-2017-141705', 'Sales': 517.405}
# {'_id': ObjectId('685966dd8718115e852b547b'), 'Order_ID': 'CA-2016-143805', 'Sales': 2104.55}
# {'_id': ObjectId('685966dd8718115e852b548e'), 'Order_ID': 'CA-2017-119284', 'Sales': 2239.936}
# {'_id': ObjectId('685966dd8718115e852b549a'), 'Order_ID': 'CA-2014-105648', 'Sales': 626.352}
# {'_id': ObjectId('685966dd8718115e852b54b1'), 'Order_ID': 'CA-2017-116988', 'Sales': 1287.45}
# {'_id': ObjectId('685966dd8718115e852b54b3'), 'Order_ID': 'CA-2016-168774', 'Sales': 535.41}
# {'_id': ObjectId('685966dd8718115e852b54c0'), 'Order_ID': 'US-2015-163825', 'Sales': 3050.376}
# {'_id': ObjectId('685966dd8718115e852b54cb'), 'Order_ID': 'CA-2016-159891', 'Sales': 1270.99}
# {'_id': ObjectId('685966dd8718115e852b54d6'), 'Order_ID': 'CA-2017-115882', 'Sales': 942.784}
# {'_id': ObjectId('685966dd8718115e852b54db'), 'Order_ID': 'CA-2016-102813', 'Sales': 528.43}
# {'_id': ObjectId('685966dd8718115e852b54e0'), 'Order_ID': 'CA-2015-133585', 'Sales': 1227.9984}
# {'_id': ObjectId('685966dd8718115e852b54e2'), 'Order_ID': 'CA-2016-116911', 'Sales': 1128.39}
# {'_id': ObjectId('685966dd8718115e852b54e7'), 'Order_ID': 'CA-2017-126914', 'Sales': 698.352}
# {'_id': ObjectId('685966dd8718115e852b54ea'), 'Order_ID': 'CA-2017-162075', 'Sales': 537.544}
# {'_id': ObjectId('685966dd8718115e852b54ed'), 'Order_ID': 'CA-2014-162992', 'Sales': 583.8}
# {'_id': ObjectId('685966dd8718115e852b54f1'), 'Order_ID': 'US-2016-150140', 'Sales': 1294.75}
# {'_id': ObjectId('685966dd8718115e852b54f2'), 'Order_ID': 'CA-2014-116666', 'Sales': 1799.97}
# {'_id': ObjectId('685966dd8718115e852b5507'), 'Order_ID': 'CA-2017-100622', 'Sales': 959.984}
# {'_id': ObjectId('685966dd8718115e852b5513'), 'Order_ID': 'CA-2015-153423', 'Sales': 1217.568}
# {'_id': ObjectId('685966dd8718115e852b5529'), 'Order_ID': 'US-2015-115343', 'Sales': 617.976}
# {'_id': ObjectId('685966dd8718115e852b552d'), 'Order_ID': 'CA-2017-135909', 'Sales': 5083.96}
# {'_id': ObjectId('685966dd8718115e852b5537'), 'Order_ID': 'CA-2016-158260', 'Sales': 686.4}
# {'_id': ObjectId('685966dd8718115e852b553a'), 'Order_ID': 'CA-2017-101805', 'Sales': 541.24}
# {'_id': ObjectId('685966dd8718115e852b554b'), 'Order_ID': 'CA-2017-103968', 'Sales': 629.64}
# {'_id': ObjectId('685966dd8718115e852b554d'), 'Order_ID': 'CA-2016-147256', 'Sales': 1927.59}
# {'_id': ObjectId('685966dd8718115e852b554f'), 'Order_ID': 'CA-2015-111038', 'Sales': 2676.672}
# {'_id': ObjectId('685966dd8718115e852b5565'), 'Order_ID': 'US-2016-144057', 'Sales': 856.656}
# {'_id': ObjectId('685966dd8718115e852b556f'), 'Order_ID': 'CA-2016-168032', 'Sales': 1439.968}
# {'_id': ObjectId('685966dd8718115e852b5571'), 'Order_ID': 'CA-2016-168032', 'Sales': 626.1}
# {'_id': ObjectId('685966dd8718115e852b5573'), 'Order_ID': 'US-2015-168704', 'Sales': 609.98}
# {'_id': ObjectId('685966dd8718115e852b557a'), 'Order_ID': 'CA-2017-130036', 'Sales': 1119.888}
# {'_id': ObjectId('685966dd8718115e852b5588'), 'Order_ID': 'CA-2017-150910', 'Sales': 934.956}
# {'_id': ObjectId('685966dd8718115e852b5593'), 'Order_ID': 'CA-2017-150266', 'Sales': 853.93}
# {'_id': ObjectId('685966dd8718115e852b5597'), 'Order_ID': 'CA-2016-157280', 'Sales': 756.8}
# {'_id': ObjectId('685966dd8718115e852b55b1'), 'Order_ID': 'US-2015-128587', 'Sales': 4899.93}
# {'_id': ObjectId('685966dd8718115e852b55b4'), 'Order_ID': 'CA-2017-159100', 'Sales': 1875.258}
# {'_id': ObjectId('685966dd8718115e852b55dc'), 'Order_ID': 'CA-2014-152268', 'Sales': 1793.98}
# {'_id': ObjectId('685966dd8718115e852b55e2'), 'Order_ID': 'CA-2016-117121', 'Sales': 9892.74}
# {'_id': ObjectId('685966dd8718115e852b55f3'), 'Order_ID': 'CA-2015-160227', 'Sales': 2621.322}
# {'_id': ObjectId('685966dd8718115e852b55f6'), 'Order_ID': 'CA-2016-132304', 'Sales': 1115.17}
# {'_id': ObjectId('685966dd8718115e852b5605'), 'Order_ID': 'CA-2014-136336', 'Sales': 828.84}
# {'_id': ObjectId('685966dd8718115e852b561f'), 'Order_ID': 'CA-2017-152933', 'Sales': 791.88}
# {'_id': ObjectId('685966dd8718115e852b562d'), 'Order_ID': 'CA-2016-135461', 'Sales': 623.96}
# {'_id': ObjectId('685966dd8718115e852b5630'), 'Order_ID': 'CA-2017-153045', 'Sales': 887.271}
# {'_id': ObjectId('685966dd8718115e852b5640'), 'Order_ID': 'CA-2015-157805', 'Sales': 555.96}
# {'_id': ObjectId('685966dd8718115e852b564a'), 'Order_ID': 'US-2017-166688', 'Sales': 1123.128}
# {'_id': ObjectId('685966dd8718115e852b564f'), 'Order_ID': 'US-2016-165505', 'Sales': 1564.29}
# {'_id': ObjectId('685966dd8718115e852b565d'), 'Order_ID': 'CA-2016-160108', 'Sales': 680.01}
# {'_id': ObjectId('685966dd8718115e852b5660'), 'Order_ID': 'CA-2016-100300', 'Sales': 4476.8}
# {'_id': ObjectId('685966dd8718115e852b5667'), 'Order_ID': 'US-2016-155768', 'Sales': 1112.94}
# {'_id': ObjectId('685966dd8718115e852b566e'), 'Order_ID': 'CA-2017-156776', 'Sales': 707.88}
# {'_id': ObjectId('685966dd8718115e852b5675'), 'Order_ID': 'CA-2017-156776', 'Sales': 1473.1}
# {'_id': ObjectId('685966dd8718115e852b5678'), 'Order_ID': 'US-2015-130512', 'Sales': 663.072}
# {'_id': ObjectId('685966dd8718115e852b5680'), 'Order_ID': 'CA-2014-103310', 'Sales': 1432.0}
# {'_id': ObjectId('685966dd8718115e852b5698'), 'Order_ID': 'CA-2017-103212', 'Sales': 1504.52}
# {'_id': ObjectId('685966dd8718115e852b56a2'), 'Order_ID': 'CA-2014-148383', 'Sales': 946.764}
# {'_id': ObjectId('685966dd8718115e852b56a5'), 'Order_ID': 'CA-2016-126732', 'Sales': 1091.168}
# {'_id': ObjectId('685966dd8718115e852b56a7'), 'Order_ID': 'CA-2016-126732', 'Sales': 568.728}
# {'_id': ObjectId('685966dd8718115e852b56b4'), 'Order_ID': 'CA-2016-127761', 'Sales': 881.93}
# {'_id': ObjectId('685966dd8718115e852b56c9'), 'Order_ID': 'US-2017-102183', 'Sales': 4305.552}
# {'_id': ObjectId('685966dd8718115e852b56cb'), 'Order_ID': 'CA-2016-100510', 'Sales': 631.96}
# {'_id': ObjectId('685966dd8718115e852b56cc'), 'Order_ID': 'CA-2017-146983', 'Sales': 1577.94}
# {'_id': ObjectId('685966dd8718115e852b56db'), 'Order_ID': 'US-2017-165456', 'Sales': 1079.316}
# {'_id': ObjectId('685966dd8718115e852b56f7'), 'Order_ID': 'CA-2016-161907', 'Sales': 769.184}
# {'_id': ObjectId('685966dd8718115e852b56ff'), 'Order_ID': 'CA-2017-121853', 'Sales': 594.816}
# {'_id': ObjectId('685966dd8718115e852b5706'), 'Order_ID': 'CA-2016-108056', 'Sales': 859.2}
# {'_id': ObjectId('685966dd8718115e852b5716'), 'Order_ID': 'CA-2017-109085', 'Sales': 899.43}
# {'_id': ObjectId('685966dd8718115e852b5717'), 'Order_ID': 'CA-2016-114860', 'Sales': 842.72}
# {'_id': ObjectId('685966dd8718115e852b571b'), 'Order_ID': 'CA-2017-148411', 'Sales': 520.464}
# {'_id': ObjectId('685966dd8718115e852b572a'), 'Order_ID': 'CA-2014-108147', 'Sales': 1676.88}
# {'_id': ObjectId('685966dd8718115e852b573f'), 'Order_ID': 'US-2017-127292', 'Sales': 542.94}
# {'_id': ObjectId('685966dd8718115e852b5743'), 'Order_ID': 'CA-2015-130848', 'Sales': 582.336}
# {'_id': ObjectId('685966dd8718115e852b5744'), 'Order_ID': 'CA-2014-125997', 'Sales': 629.95}
# {'_id': ObjectId('685966dd8718115e852b5745'), 'Order_ID': 'CA-2014-125997', 'Sales': 631.782}
# {'_id': ObjectId('685966dd8718115e852b5746'), 'Order_ID': 'CA-2014-125997', 'Sales': 801.568}
# {'_id': ObjectId('685966dd8718115e852b5749'), 'Order_ID': 'CA-2014-125997', 'Sales': 1349.91}
# {'_id': ObjectId('685966dd8718115e852b574e'), 'Order_ID': 'CA-2016-105459', 'Sales': 1591.02}
# {'_id': ObjectId('685966dd8718115e852b5750'), 'Order_ID': 'CA-2014-152618', 'Sales': 574.91}
# {'_id': ObjectId('685966dd8718115e852b5752'), 'Order_ID': 'CA-2017-162789', 'Sales': 1071.0}
# {'_id': ObjectId('685966dd8718115e852b5757'), 'Order_ID': 'CA-2015-164777', 'Sales': 2803.92}
# {'_id': ObjectId('685966dd8718115e852b5760'), 'Order_ID': 'CA-2014-145254', 'Sales': 604.752}
# {'_id': ObjectId('685966dd8718115e852b5764'), 'Order_ID': 'CA-2014-116246', 'Sales': 3785.292}
# {'_id': ObjectId('685966dd8718115e852b5767'), 'Order_ID': 'CA-2014-152100', 'Sales': 1212.96}
# {'_id': ObjectId('685966dd8718115e852b5768'), 'Order_ID': 'CA-2015-166219', 'Sales': 1099.96}
# {'_id': ObjectId('685966dd8718115e852b5789'), 'Order_ID': 'US-2017-109610', 'Sales': 701.96}
# {'_id': ObjectId('685966dd8718115e852b579f'), 'Order_ID': 'CA-2016-164770', 'Sales': 781.864}
# {'_id': ObjectId('685966dd8718115e852b57a1'), 'Order_ID': 'CA-2017-130505', 'Sales': 673.344}
# {'_id': ObjectId('685966dd8718115e852b57a3'), 'Order_ID': 'CA-2015-156566', 'Sales': 572.8}
# {'_id': ObjectId('685966dd8718115e852b57a5'), 'Order_ID': 'CA-2017-111738', 'Sales': 2022.272}
# {'_id': ObjectId('685966dd8718115e852b57a8'), 'Order_ID': 'CA-2016-105207', 'Sales': 1592.85}
# {'_id': ObjectId('685966dd8718115e852b57b3'), 'Order_ID': 'CA-2016-113607', 'Sales': 1091.93}
# {'_id': ObjectId('685966dd8718115e852b57b8'), 'Order_ID': 'CA-2014-149104', 'Sales': 689.82}
# {'_id': ObjectId('685966dd8718115e852b57bc'), 'Order_ID': 'CA-2016-125220', 'Sales': 1649.75}
# {'_id': ObjectId('685966dd8718115e852b57e2'), 'Order_ID': 'CA-2015-147690', 'Sales': 577.584}
# {'_id': ObjectId('685966dd8718115e852b57f0'), 'Order_ID': 'CA-2014-130428', 'Sales': 1125.488}
# {'_id': ObjectId('685966dd8718115e852b57fd'), 'Order_ID': 'CA-2017-152975', 'Sales': 1079.85}
# {'_id': ObjectId('685966dd8718115e852b5800'), 'Order_ID': 'CA-2017-152975', 'Sales': 589.41}
# {'_id': ObjectId('685966dd8718115e852b5822'), 'Order_ID': 'CA-2014-128524', 'Sales': 2033.584}
# {'_id': ObjectId('685966dd8718115e852b5824'), 'Order_ID': 'CA-2017-160633', 'Sales': 899.982}
# {'_id': ObjectId('685966dd8718115e852b5836'), 'Order_ID': 'CA-2014-151330', 'Sales': 1628.82}
# {'_id': ObjectId('685966dd8718115e852b5838'), 'Order_ID': 'CA-2014-124702', 'Sales': 730.2}
# {'_id': ObjectId('685966dd8718115e852b583a'), 'Order_ID': 'CA-2015-116638', 'Sales': 4297.644}
# {'_id': ObjectId('685966dd8718115e852b5844'), 'Order_ID': 'CA-2016-107104', 'Sales': 3406.664}
# {'_id': ObjectId('685966dd8718115e852b5847'), 'Order_ID': 'CA-2016-107104', 'Sales': 595.38}
# {'_id': ObjectId('685966dd8718115e852b584d'), 'Order_ID': 'CA-2014-156160', 'Sales': 579.528}
# {'_id': ObjectId('685966dd8718115e852b584f'), 'Order_ID': 'CA-2016-160717', 'Sales': 3023.928}
# {'_id': ObjectId('685966dd8718115e852b585c'), 'Order_ID': 'CA-2016-114867', 'Sales': 1499.97}
# {'_id': ObjectId('685966dd8718115e852b5863'), 'Order_ID': 'CA-2015-130113', 'Sales': 668.16}
# {'_id': ObjectId('685966dd8718115e852b586c'), 'Order_ID': 'US-2017-135986', 'Sales': 503.96}
# {'_id': ObjectId('685966dd8718115e852b586e'), 'Order_ID': 'CA-2015-130183', 'Sales': 613.9992}
# {'_id': ObjectId('685966dd8718115e852b587a'), 'Order_ID': 'CA-2017-147032', 'Sales': 849.95}
# {'_id': ObjectId('685966dd8718115e852b5883'), 'Order_ID': 'CA-2014-114251', 'Sales': 1080.096}
# {'_id': ObjectId('685966dd8718115e852b5892'), 'Order_ID': 'CA-2017-167395', 'Sales': 979.95}
# {'_id': ObjectId('685966dd8718115e852b5895'), 'Order_ID': 'CA-2014-111962', 'Sales': 807.75}
# {'_id': ObjectId('685966dd8718115e852b5897'), 'Order_ID': 'CA-2014-114321', 'Sales': 500.24}
# {'_id': ObjectId('685966dd8718115e852b5899'), 'Order_ID': 'CA-2014-114321', 'Sales': 896.99}
# {'_id': ObjectId('685966dd8718115e852b58a0'), 'Order_ID': 'CA-2015-117086', 'Sales': 4404.9}
# {'_id': ObjectId('685966dd8718115e852b58a7'), 'Order_ID': 'US-2014-140914', 'Sales': 797.944}
# {'_id': ObjectId('685966dd8718115e852b58b2'), 'Order_ID': 'CA-2016-146913', 'Sales': 1403.92}
# {'_id': ObjectId('685966dd8718115e852b58c1'), 'Order_ID': 'CA-2014-169019', 'Sales': 2177.584}
# {'_id': ObjectId('685966dd8718115e852b58c8'), 'Order_ID': 'CA-2016-153178', 'Sales': 673.568}
# {'_id': ObjectId('685966dd8718115e852b58ce'), 'Order_ID': 'CA-2017-144491', 'Sales': 1023.332}
# {'_id': ObjectId('685966dd8718115e852b58cf'), 'Order_ID': 'CA-2017-144491', 'Sales': 600.558}
# {'_id': ObjectId('685966dd8718115e852b58eb'), 'Order_ID': 'CA-2015-162201', 'Sales': 516.96}
# {'_id': ObjectId('685966dd8718115e852b58fc'), 'Order_ID': 'CA-2017-130302', 'Sales': 895.944}
# {'_id': ObjectId('685966dd8718115e852b590a'), 'Order_ID': 'CA-2017-169327', 'Sales': 511.5}
# {'_id': ObjectId('685966dd8718115e852b5914'), 'Order_ID': 'CA-2015-164301', 'Sales': 3393.68}
# {'_id': ObjectId('685966dd8718115e852b591d'), 'Order_ID': 'US-2015-116981', 'Sales': 1085.42}
# {'_id': ObjectId('685966dd8718115e852b5927'), 'Order_ID': 'US-2017-166324', 'Sales': 848.544}
# {'_id': ObjectId('685966dd8718115e852b592a'), 'Order_ID': 'CA-2016-122581', 'Sales': 573.174}
# {'_id': ObjectId('685966dd8718115e852b5946'), 'Order_ID': 'US-2015-129007', 'Sales': 717.72}
# {'_id': ObjectId('685966dd8718115e852b5952'), 'Order_ID': 'CA-2016-149272', 'Sales': 528.43}
# {'_id': ObjectId('685966dd8718115e852b5958'), 'Order_ID': 'CA-2015-159534', 'Sales': 1087.936}
# {'_id': ObjectId('685966dd8718115e852b595c'), 'Order_ID': 'CA-2016-129630', 'Sales': 2799.96}
# {'_id': ObjectId('685966dd8718115e852b595e'), 'Order_ID': 'CA-2015-104948', 'Sales': 683.332}
# {'_id': ObjectId('685966dd8718115e852b5969'), 'Order_ID': 'CA-2014-143371', 'Sales': 998.82}
# {'_id': ObjectId('685966dd8718115e852b596e'), 'Order_ID': 'CA-2017-121559', 'Sales': 1925.88}
# {'_id': ObjectId('685966dd8718115e852b596f'), 'Order_ID': 'CA-2017-121559', 'Sales': 2405.2}
# {'_id': ObjectId('685966dd8718115e852b5983'), 'Order_ID': 'CA-2017-153871', 'Sales': 735.98}

# %%
###6. Fetch the top 3 orders with the highest Profit

profit_orders  = collections.find().sort({'profit':-1}).limit(3)
for order in profit_orders:
  print(order)
# Out:
# {'_id': ObjectId('685966dd8718115e852b3293'), 'Row_ID': 1, 'Order_ID': 'CA-2016-152156', 'Order_Date': '11/8/2016', 'Ship_Date': '11/11/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'CG-12520', 'Customer_Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal_Code': 42420, 'Region': 'South', 'Product_ID': 'FUR-BO-10001798', 'Category': 'Furniture', 'SubCategory': 'Bookcases', 'Product_Name': 'Bush Somerset Collection Bookcase', 'Sales': 261.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 41.9136}
# {'_id': ObjectId('685966dd8718115e852b3294'), 'Row_ID': 2, 'Order_ID': 'CA-2016-152156', 'Order_Date': '11/8/2016', 'Ship_Date': '11/11/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'CG-12520', 'Customer_Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal_Code': 42420, 'Region': 'South', 'Product_ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'SubCategory': 'Chairs', 'Product_Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 731.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 219.582}
# {'_id': ObjectId('685966dd8718115e852b3295'), 'Row_ID': 3, 'Order_ID': 'CA-2016-138688', 'Order_Date': '6/12/2016', 'Ship_Date': '6/16/2016', 'Ship_Mode': 'Second Class', 'Customer_ID': 'DV-13045', 'Customer_Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal_Code': 90036, 'Region': 'West', 'Product_ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'SubCategory': 'Labels', 'Product_Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}

# %%
###7. Update all orders with Ship Mode as "First Class" to "Premium Class.

#Before update
pipeline = [
    {"$group":{"_id":'$Ship_Mode','count':{'$sum':1}}},
    {"$sort":{'count':-1}}
]

result = collections.aggregate(pipeline)
for order in result:
  print(order)

#Update
update_result = collections.update_many(
    {'Ship_Mode':'First Class'},
    {'$set':{'Ship_Mode':'Premium Class'}}
    )
print(f'Modified {update_result.modified_count} records')

#After Update
result = collections.aggregate(pipeline)
for order in result:
  print(order)
# Out:
# {'_id': 'Standard Class', 'count': 5968}
# {'_id': 'Second Class', 'count': 1945}
# {'_id': 'First Class', 'count': 1538}
# {'_id': 'Same Day', 'count': 543}
# Modified 1538 records
# {'_id': 'Standard Class', 'count': 5968}
# {'_id': 'Second Class', 'count': 1945}
# {'_id': 'Premium Class', 'count': 1538}
# {'_id': 'Same Day', 'count': 543}

# %%
###8. Delete all orders where Sales is less than 50

#Before delete
result = collections.count_documents({'Sales':{'$lt':50}})
print(f'Total records to be deleted {result}')

deleted_result = collections.delete_many({'Sales':{'$lt':50}})
print(f"Deleted {deleted_result.deleted_count} documents where Sales < 50.")

#After delete
result = collections.count_documents({'Sales':{'$lt':50}})
print(f'Total records to be deleted {result}')
# Out:
# Total records to be deleted 4849
# Deleted 4849 documents where Sales < 50.
# Total records to be deleted 0

# %%
###9. Use aggregation to group orders by Region and calculate total sales per region

pipeline = [
    {'$group':{'_id':'$Region','count':{'$sum':'$Sales'}}},
    {'$sort':{'count':-1}}
  ]

result = collections.aggregate(pipeline)

for order in result:
  print(order)
# Out:
# {'_id': 'West', 'count': 694686.6195}
# {'_id': 'East', 'count': 651137.705}
# {'_id': 'Central', 'count': 479611.8458}
# {'_id': 'South', 'count': 376023.312}

# %%
###10. Fetch all distinct values for Ship Mode from the collection

ship_modes = collections.distinct('Ship_Mode')
for r in ship_modes:
  print(r)
# Out:
# Premium Class
# Same Day
# Second Class
# Standard Class

# %%
###11. Count the number of orders for each category

pipeline =[
    {'$group':{'_id':'$Category','num_of_orders':{'$sum':1}}},
    {'$sort':{'num_of_orders':-1}}
]

result = collections.aggregate(pipeline)

for r in result:
  print(r)
# Out:
# {'_id': 'Office Supplies', 'num_of_orders': 2076}
# {'_id': 'Furniture', 'num_of_orders': 1573}
# {'_id': 'Technology', 'num_of_orders': 1496}
